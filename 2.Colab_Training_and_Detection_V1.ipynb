# %% [markdown]
# # 0. Setup Paths

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
#rm -rf /content/drive/MyDrive/TFOD/Tensorflow/

# %%
import tensorflow as tf

# %%
print(tf.config.list_physical_devices('GPU'))
# Out:
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %%
# !nvidia-smi
# Out:
# Sat Oct 15 17:24:30 2022
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 460.32.03    Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   51C    P8    10W /  70W |      3MiB / 15109MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %%
import os

# %%
pwd
# Out:
# '/content'

# %%
########################################################
##################  For Colab  #########################
########################################################

if not os.path.exists("/content/drive/MyDrive/TFOD/"):
  # !mkdir -p "/content/drive/MyDrive/TFOD/"

# %%
cd '/content/drive/MyDrive/TFOD/'
# Out:
# /content/drive/MyDrive/TFOD

# %%
CUSTOM_MODEL_NAME = 'my_ssd_resnet50_v1_fpn_640x640' 
PRETRAINED_MODEL_NAME = 'ssd_resnet50_v1_fpn_640x640_coco17_tpu-8'
PRETRAINED_MODEL_URL = 'http://download.tensorflow.org/models/object_detection/tf2/20200711/ssd_resnet50_v1_fpn_640x640_coco17_tpu-8.tar.gz'
#TF_RECORD_SCRIPT_NAME = 'generate_tfrecord.py'
TF_RECORD_SCRIPT_NAME = 'CSV_generate_tfrecord.py'
LABEL_MAP_NAME = 'label_map.pbtxt'

# %%
paths = {
    'WORKSPACE_PATH': os.path.join('Tensorflow', 'workspace'),
    'SCRIPTS_PATH': os.path.join('Tensorflow','scripts'),
    'APIMODEL_PATH': os.path.join('Tensorflow','models'),
    'ANNOTATION_PATH': os.path.join('Tensorflow', 'workspace','annotations'),
    'IMAGE_PATH': os.path.join('Tensorflow', 'workspace','images'),
    'MODEL_PATH': os.path.join('Tensorflow', 'workspace','models'),
    'PRETRAINED_MODEL_PATH': os.path.join('Tensorflow', 'workspace','pre-trained-models'),
    'CHECKPOINT_PATH': os.path.join('Tensorflow', 'workspace','models',CUSTOM_MODEL_NAME), 
    'OUTPUT_PATH': os.path.join('Tensorflow', 'workspace','models',CUSTOM_MODEL_NAME, 'export'), 
    'TFJS_PATH':os.path.join('Tensorflow', 'workspace','models',CUSTOM_MODEL_NAME, 'tfjsexport'), 
    'TFLITE_PATH':os.path.join('Tensorflow', 'workspace','models',CUSTOM_MODEL_NAME, 'tfliteexport'), 
    'PROTOC_PATH':os.path.join('Tensorflow','protoc')
 }

# %%
files = {
    'PIPELINE_CONFIG':os.path.join('Tensorflow', 'workspace','models', CUSTOM_MODEL_NAME, 'pipeline.config'),
    'TF_RECORD_SCRIPT': os.path.join(paths['SCRIPTS_PATH'], TF_RECORD_SCRIPT_NAME), 
    'LABELMAP': os.path.join(paths['ANNOTATION_PATH'], LABEL_MAP_NAME)
}

# %%
files
# Out:
# {'PIPELINE_CONFIG': 'Tensorflow/workspace/models/my_ssd_resnet50_v1_fpn_640x640/pipeline.config',
#  'TF_RECORD_SCRIPT': 'Tensorflow/scripts/CSV_generate_tfrecord.py',
#  'LABELMAP': 'Tensorflow/workspace/annotations/label_map.pbtxt'}

# %%
for path in paths.values():
    if not os.path.exists(path):
        if os.name == 'posix':
            # !mkdir -p {path}
        if os.name == 'nt':
            # !mkdir {path}

# %%
paths
# Out:
# {'WORKSPACE_PATH': 'Tensorflow/workspace',
#  'SCRIPTS_PATH': 'Tensorflow/scripts',
#  'APIMODEL_PATH': 'Tensorflow/models',
#  'ANNOTATION_PATH': 'Tensorflow/workspace/annotations',
#  'IMAGE_PATH': 'Tensorflow/workspace/images',
#  'MODEL_PATH': 'Tensorflow/workspace/models',
#  'PRETRAINED_MODEL_PATH': 'Tensorflow/workspace/pre-trained-models',
#  'CHECKPOINT_PATH': 'Tensorflow/workspace/models/my_ssd_resnet50_v1_fpn_640x640',
#  'OUTPUT_PATH': 'Tensorflow/workspace/models/my_ssd_resnet50_v1_fpn_640x640/export',
#  'TFJS_PATH': 'Tensorflow/workspace/models/my_ssd_resnet50_v1_fpn_640x640/tfjsexport',
#  'TFLITE_PATH': 'Tensorflow/workspace/models/my_ssd_resnet50_v1_fpn_640x640/tfliteexport',
#  'PROTOC_PATH': 'Tensorflow/protoc'}

# %% [markdown]
# # 1. Download TF Models Pretrained Models from Tensorflow Model Zoo and Install TFOD

# %%
# https://www.tensorflow.org/install/source_windows

# %%
if os.name=='nt':
    # !pip install wget
    import wget

# %%
if not os.path.exists(os.path.join(paths['APIMODEL_PATH'], 'research', 'object_detection')):
    # !git clone https://github.com/tensorflow/models {paths['APIMODEL_PATH']}
# Out:
# Cloning into 'Tensorflow/models'...
# remote: Enumerating objects: 77987, done.
# remote: Counting objects: 100% (395/395), done.
# remote: Compressing objects: 100% (200/200), done.
# remote: Total 77987 (delta 239), reused 321 (delta 193), pack-reused 77592
# Receiving objects: 100% (77987/77987), 593.50 MiB | 15.84 MiB/s, done.
# Resolving deltas: 100% (55394/55394), done.
# Checking out files: 100% (3180/3180), done.

# %%
# Install Tensorflow Object Detection 
if os.name=='posix':  
    # !apt-get install protobuf-compiler
    # !cd Tensorflow/models/research && protoc object_detection/protos/*.proto --python_out=. && cp object_detection/packages/tf2/setup.py . && python -m pip install . 
    
if os.name=='nt':
    #url="https://github.com/protocolbuffers/protobuf/releases/download/v3.15.6/protoc-3.15.6-win64.zip"
    url="https://github.com/protocolbuffers/protobuf/releases/download/v3.19.6/protoc-3.19.6-win64.zip"
    wget.download(url)
    #!move protoc-3.15.6-win64.zip {paths['PROTOC_PATH']}
    # !move protoc-3.19.6-win64.zip {paths['PROTOC_PATH']}
    #!cd {paths['PROTOC_PATH']} && tar -xf protoc-3.15.6-win64.zip
    # !cd {paths['PROTOC_PATH']} && tar -xf protoc-3.19.6-win64.zip
    os.environ['PATH'] += os.pathsep + os.path.abspath(os.path.join(paths['PROTOC_PATH'], 'bin'))   
    # !cd Tensorflow/models/research && protoc object_detection/protos/*.proto --python_out=. && copy object_detection\\packages\\tf2\\setup.py setup.py && python setup.py build && python setup.py install
    # !cd Tensorflow/models/research/slim && pip install -e .
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# protobuf-compiler is already the newest version (3.0.0-9.1ubuntu1).
# The following package was automatically installed and is no longer required:
#   libnvidia-common-460
# Use 'apt autoremove' to remove it.
# 0 upgraded, 0 newly installed, 0 to remove and 12 not upgraded.
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Processing /content/drive/MyDrive/TFOD/Tensorflow/models/research
#   DEPRECATION: A future pip version will change local packages to be built in-place without first copying to a temporary directory. We recommend you use --use-feature=in-tree-build to test your packages with this new behavior before it becomes the default.
#    pip 21.3 will remove support for this functionality. You can find discussion regarding this at https://github.com/pypa/pip/issues/7555.
# Collecting avro-python3
#   Downloading avro-python3-1.10.2.tar.gz (38 kB)
# Collecting apache-beam
#   Downloading apache_beam-2.41.0-cp37-cp37m-manylinux2010_x86_64.whl (10.9 MB)
#      |████████████████████████████████| 10.9 MB 17.0 MB/s
# Requirement already satisfied: pillow in /usr/local/lib/python3.7/dist-packages (from object-detection==0.1) (7.1.2)
# Requirement already satisfied: lxml in /usr/local/lib/python3.7/dist-packages (from object-detection==0.1) (4.9.1)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.7/dist-packages (from object-detection==0.1) (3.2.2)
# Requirement already satisfied: Cython in /usr/local/lib/python3.7/dist-packages (from object-detection==0.1) (0.29.32)
# Requirement already satisfied: contextlib2 in /usr/local/lib/python3.7/dist-packages (from object-detection==0.1) (0.5.5)
# Collecting tf-slim
#   Downloading tf_slim-1.1.0-py2.py3-none-any.whl (352 kB)
#      |████████████████████████████████| 352 kB 70.3 MB/s
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from object-detection==0.1) (1.15.0)
# Requirement already satisfied: pycocotools in /usr/local/lib/python3.7/dist-packages (from object-detection==0.1) (2.0.5)
# Collecting lvis
#   Downloading lvis-0.5.3-py3-none-any.whl (14 kB)
# Requirement already satisfied: scipy in /usr/local/lib/python3.7/dist-packages (from object-detection==0.1) (1.7.3)
# Requirement already satisfied: pandas in /usr/local/lib/python3.7/dist-packages (from object-detection==0.1) (1.3.5)
# Collecting tf-models-official>=2.5.1
#   Downloading tf_models_official-2.10.0-py2.py3-none-any.whl (2.2 MB)
#      |████████████████████████████████| 2.2 MB 48.2 MB/s
# Collecting tensorflow_io
#   Downloading tensorflow_io-0.27.0-cp37-cp37m-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (25.0 MB)
#      |████████████████████████████████| 25.0 MB 1.4 MB/s
# Requirement already satisfied: keras in /usr/local/lib/python3.7/dist-packages (from object-detection==0.1) (2.9.0)
# Collecting pyparsing==2.4.7
#   Downloading pyparsing-2.4.7-py2.py3-none-any.whl (67 kB)
#      |████████████████████████████████| 67 kB 6.2 MB/s
# Collecting sacrebleu<=2.2.0
#   Downloading sacrebleu-2.2.0-py3-none-any.whl (116 kB)
#      |████████████████████████████████| 116 kB 64.9 MB/s
# Requirement already satisfied: tabulate>=0.8.9 in /usr/local/lib/python3.7/dist-packages (from sacrebleu<=2.2.0->object-detection==0.1) (0.8.10)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.7/dist-packages (from sacrebleu<=2.2.0->object-detection==0.1) (1.21.6)
# Collecting portalocker
#   Downloading portalocker-2.5.1-py2.py3-none-any.whl (15 kB)
# Collecting colorama
#   Downloading colorama-0.4.5-py2.py3-none-any.whl (16 kB)
# Requirement already satisfied: regex in /usr/local/lib/python3.7/dist-packages (from sacrebleu<=2.2.0->object-detection==0.1) (2022.6.2)
# Collecting pyyaml<6.0,>=5.1
#   Downloading PyYAML-5.4.1-cp37-cp37m-manylinux1_x86_64.whl (636 kB)
#      |████████████████████████████████| 636 kB 68.6 MB/s
# Requirement already satisfied: google-api-python-client>=1.6.7 in /usr/local/lib/python3.7/dist-packages (from tf-models-official>=2.5.1->object-detection==0.1) (1.12.11)
# Collecting immutabledict
#   Downloading immutabledict-2.2.1-py3-none-any.whl (4.0 kB)
# Collecting tensorflow-addons
#   Downloading tensorflow_addons-0.18.0-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.1 MB)
#      |████████████████████████████████| 1.1 MB 22.1 MB/s
# Requirement already satisfied: psutil>=5.4.3 in /usr/local/lib/python3.7/dist-packages (from tf-models-official>=2.5.1->object-detection==0.1) (5.4.8)
# Requirement already satisfied: kaggle>=1.3.9 in /usr/local/lib/python3.7/dist-packages (from tf-models-official>=2.5.1->object-detection==0.1) (1.5.12)
# Requirement already satisfied: oauth2client in /usr/local/lib/python3.7/dist-packages (from tf-models-official>=2.5.1->object-detection==0.1) (4.1.3)
# Requirement already satisfied: tensorflow-hub>=0.6.0 in /usr/local/lib/python3.7/dist-packages (from tf-models-official>=2.5.1->object-detection==0.1) (0.12.0)
# Collecting sentencepiece
#   Downloading sentencepiece-0.1.97-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.3 MB)
#      |████████████████████████████████| 1.3 MB 55.0 MB/s
# Requirement already satisfied: gin-config in /usr/local/lib/python3.7/dist-packages (from tf-models-official>=2.5.1->object-detection==0.1) (0.5.0)
# Requirement already satisfied: tensorflow-datasets in /usr/local/lib/python3.7/dist-packages (from tf-models-official>=2.5.1->object-detection==0.1) (4.6.0)
# Collecting tensorflow~=2.10.0
#   Downloading tensorflow-2.10.0-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (578.0 MB)
#      |████████████████████████████████| 578.0 MB 15 kB/s
# Collecting opencv-python-headless==4.5.2.52
#   Downloading opencv_python_headless-4.5.2.52-cp37-cp37m-manylinux2014_x86_64.whl (38.2 MB)
#      |████████████████████████████████| 38.2 MB 1.2 MB/s
# Collecting tensorflow-model-optimization>=0.4.1
#   Downloading tensorflow_model_optimization-0.7.3-py2.py3-none-any.whl (238 kB)
#      |████████████████████████████████| 238 kB 47.6 MB/s
# Collecting py-cpuinfo>=3.3.0
#   Downloading py-cpuinfo-8.0.0.tar.gz (99 kB)
#      |████████████████████████████████| 99 kB 9.8 MB/s
# Collecting seqeval
#   Downloading seqeval-1.2.2.tar.gz (43 kB)
#      |████████████████████████████████| 43 kB 2.1 MB/s
# Collecting tensorflow-text~=2.10.0
#   Downloading tensorflow_text-2.10.0-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (5.9 MB)
#      |████████████████████████████████| 5.9 MB 51.4 MB/s
# Requirement already satisfied: google-api-core<3dev,>=1.21.0 in /usr/local/lib/python3.7/dist-packages (from google-api-python-client>=1.6.7->tf-models-official>=2.5.1->object-detection==0.1) (1.31.6)
# Requirement already satisfied: google-auth-httplib2>=0.0.3 in /usr/local/lib/python3.7/dist-packages (from google-api-python-client>=1.6.7->tf-models-official>=2.5.1->object-detection==0.1) (0.0.4)
# Requirement already satisfied: uritemplate<4dev,>=3.0.0 in /usr/local/lib/python3.7/dist-packages (from google-api-python-client>=1.6.7->tf-models-official>=2.5.1->object-detection==0.1) (3.0.1)
# Requirement already satisfied: httplib2<1dev,>=0.15.0 in /usr/local/lib/python3.7/dist-packages (from google-api-python-client>=1.6.7->tf-models-official>=2.5.1->object-detection==0.1) (0.17.4)
# Requirement already satisfied: google-auth<3dev,>=1.16.0 in /usr/local/lib/python3.7/dist-packages (from google-api-python-client>=1.6.7->tf-models-official>=2.5.1->object-detection==0.1) (1.35.0)
# Requirement already satisfied: googleapis-common-protos<2.0dev,>=1.6.0 in /usr/local/lib/python3.7/dist-packages (from google-api-core<3dev,>=1.21.0->google-api-python-client>=1.6.7->tf-models-official>=2.5.1->object-detection==0.1) (1.56.4)
# Requirement already satisfied: setuptools>=40.3.0 in /usr/local/lib/python3.7/dist-packages (from google-api-core<3dev,>=1.21.0->google-api-python-client>=1.6.7->tf-models-official>=2.5.1->object-detection==0.1) (57.4.0)
# Requirement already satisfied: protobuf<4.0.0dev,>=3.12.0 in /usr/local/lib/python3.7/dist-packages (from google-api-core<3dev,>=1.21.0->google-api-python-client>=1.6.7->tf-models-official>=2.5.1->object-detection==0.1) (3.17.3)
# Requirement already satisfied: packaging>=14.3 in /usr/local/lib/python3.7/dist-packages (from google-api-core<3dev,>=1.21.0->google-api-python-client>=1.6.7->tf-models-official>=2.5.1->object-detection==0.1) (21.3)
# Requirement already satisfied: pytz in /usr/local/lib/python3.7/dist-packages (from google-api-core<3dev,>=1.21.0->google-api-python-client>=1.6.7->tf-models-official>=2.5.1->object-detection==0.1) (2022.4)
# Requirement already satisfied: requests<3.0.0dev,>=2.18.0 in /usr/local/lib/python3.7/dist-packages (from google-api-core<3dev,>=1.21.0->google-api-python-client>=1.6.7->tf-models-official>=2.5.1->object-detection==0.1) (2.23.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.7/dist-packages (from google-auth<3dev,>=1.16.0->google-api-python-client>=1.6.7->tf-models-official>=2.5.1->object-detection==0.1) (4.9)
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from google-auth<3dev,>=1.16.0->google-api-python-client>=1.6.7->tf-models-official>=2.5.1->object-detection==0.1) (4.2.4)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.7/dist-packages (from google-auth<3dev,>=1.16.0->google-api-python-client>=1.6.7->tf-models-official>=2.5.1->object-detection==0.1) (0.2.8)
# Requirement already satisfied: urllib3 in /usr/local/lib/python3.7/dist-packages (from kaggle>=1.3.9->tf-models-official>=2.5.1->object-detection==0.1) (1.24.3)
# Requirement already satisfied: certifi in /usr/local/lib/python3.7/dist-packages (from kaggle>=1.3.9->tf-models-official>=2.5.1->object-detection==0.1) (2022.9.24)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.7/dist-packages (from kaggle>=1.3.9->tf-models-official>=2.5.1->object-detection==0.1) (4.64.1)
# Requirement already satisfied: python-slugify in /usr/local/lib/python3.7/dist-packages (from kaggle>=1.3.9->tf-models-official>=2.5.1->object-detection==0.1) (6.1.2)
# Requirement already satisfied: python-dateutil in /usr/local/lib/python3.7/dist-packages (from kaggle>=1.3.9->tf-models-official>=2.5.1->object-detection==0.1) (2.8.2)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /usr/local/lib/python3.7/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3dev,>=1.16.0->google-api-python-client>=1.6.7->tf-models-official>=2.5.1->object-detection==0.1) (0.4.8)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0dev,>=2.18.0->google-api-core<3dev,>=1.21.0->google-api-python-client>=1.6.7->tf-models-official>=2.5.1->object-detection==0.1) (2.10)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0dev,>=2.18.0->google-api-core<3dev,>=1.21.0->google-api-python-client>=1.6.7->tf-models-official>=2.5.1->object-detection==0.1) (3.0.4)
# Requirement already satisfied: typing-extensions>=3.6.6 in /usr/local/lib/python3.7/dist-packages (from tensorflow~=2.10.0->tf-models-official>=2.5.1->object-detection==0.1) (4.1.1)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow~=2.10.0->tf-models-official>=2.5.1->object-detection==0.1) (1.6.3)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow~=2.10.0->tf-models-official>=2.5.1->object-detection==0.1) (2.0.1)
# Requirement already satisfied: wrapt>=1.11.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow~=2.10.0->tf-models-official>=2.5.1->object-detection==0.1) (1.14.1)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.7/dist-packages (from tensorflow~=2.10.0->tf-models-official>=2.5.1->object-detection==0.1) (1.49.1)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /usr/local/lib/python3.7/dist-packages (from tensorflow~=2.10.0->tf-models-official>=2.5.1->object-detection==0.1) (0.27.0)
# Requirement already satisfied: h5py>=2.9.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow~=2.10.0->tf-models-official>=2.5.1->object-detection==0.1) (3.1.0)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.7/dist-packages (from tensorflow~=2.10.0->tf-models-official>=2.5.1->object-detection==0.1) (3.3.0)
# Requirement already satisfied: absl-py>=1.0.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow~=2.10.0->tf-models-official>=2.5.1->object-detection==0.1) (1.2.0)
# Collecting flatbuffers>=2.0
#   Downloading flatbuffers-22.9.24-py2.py3-none-any.whl (26 kB)
# Collecting keras
#   Downloading keras-2.10.0-py2.py3-none-any.whl (1.7 MB)
#      |████████████████████████████████| 1.7 MB 47.5 MB/s
# Requirement already satisfied: keras-preprocessing>=1.1.1 in /usr/local/lib/python3.7/dist-packages (from tensorflow~=2.10.0->tf-models-official>=2.5.1->object-detection==0.1) (1.1.2)
# Requirement already satisfied: gast<=0.4.0,>=0.2.1 in /usr/local/lib/python3.7/dist-packages (from tensorflow~=2.10.0->tf-models-official>=2.5.1->object-detection==0.1) (0.4.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.7/dist-packages (from tensorflow~=2.10.0->tf-models-official>=2.5.1->object-detection==0.1) (0.2.0)
# Requirement already satisfied: libclang>=13.0.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow~=2.10.0->tf-models-official>=2.5.1->object-detection==0.1) (14.0.6)
# Collecting tensorboard<2.11,>=2.10
#   Downloading tensorboard-2.10.1-py3-none-any.whl (5.9 MB)
#      |████████████████████████████████| 5.9 MB 57.3 MB/s
# Collecting tensorflow-estimator<2.11,>=2.10.0
#   Downloading tensorflow_estimator-2.10.0-py2.py3-none-any.whl (438 kB)
#      |████████████████████████████████| 438 kB 44.3 MB/s
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.7/dist-packages (from astunparse>=1.6.0->tensorflow~=2.10.0->tf-models-official>=2.5.1->object-detection==0.1) (0.37.1)
# Requirement already satisfied: cached-property in /usr/local/lib/python3.7/dist-packages (from h5py>=2.9.0->tensorflow~=2.10.0->tf-models-official>=2.5.1->object-detection==0.1) (1.5.2)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.7/dist-packages (from tensorboard<2.11,>=2.10->tensorflow~=2.10.0->tf-models-official>=2.5.1->object-detection==0.1) (3.4.1)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard<2.11,>=2.10->tensorflow~=2.10.0->tf-models-official>=2.5.1->object-detection==0.1) (0.6.1)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in /usr/local/lib/python3.7/dist-packages (from tensorboard<2.11,>=2.10->tensorflow~=2.10.0->tf-models-official>=2.5.1->object-detection==0.1) (0.4.6)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.7/dist-packages (from tensorboard<2.11,>=2.10->tensorflow~=2.10.0->tf-models-official>=2.5.1->object-detection==0.1) (1.0.1)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard<2.11,>=2.10->tensorflow~=2.10.0->tf-models-official>=2.5.1->object-detection==0.1) (1.8.1)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.7/dist-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.11,>=2.10->tensorflow~=2.10.0->tf-models-official>=2.5.1->object-detection==0.1) (1.3.1)
# Requirement already satisfied: importlib-metadata>=4.4 in /usr/local/lib/python3.7/dist-packages (from markdown>=2.6.8->tensorboard<2.11,>=2.10->tensorflow~=2.10.0->tf-models-official>=2.5.1->object-detection==0.1) (5.0.0)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata>=4.4->markdown>=2.6.8->tensorboard<2.11,>=2.10->tensorflow~=2.10.0->tf-models-official>=2.5.1->object-detection==0.1) (3.9.0)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.7/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.11,>=2.10->tensorflow~=2.10.0->tf-models-official>=2.5.1->object-detection==0.1) (3.2.1)
# Requirement already satisfied: dm-tree~=0.1.1 in /usr/local/lib/python3.7/dist-packages (from tensorflow-model-optimization>=0.4.1->tf-models-official>=2.5.1->object-detection==0.1) (0.1.7)
# Collecting pymongo<4.0.0,>=3.8.0
#   Downloading pymongo-3.12.3-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (508 kB)
#      |████████████████████████████████| 508 kB 67.7 MB/s
# Requirement already satisfied: pyarrow<8.0.0,>=0.15.1 in /usr/local/lib/python3.7/dist-packages (from apache-beam->object-detection==0.1) (6.0.1)
# Collecting fastavro<2,>=0.23.6
#   Downloading fastavro-1.6.1-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.4 MB)
#      |████████████████████████████████| 2.4 MB 50.5 MB/s
# Collecting dill<0.3.2,>=0.3.1.1
#   Downloading dill-0.3.1.1.tar.gz (151 kB)
#      |████████████████████████████████| 151 kB 70.2 MB/s
# Collecting hdfs<3.0.0,>=2.1.0
#   Downloading hdfs-2.7.0-py3-none-any.whl (34 kB)
# Collecting proto-plus<2,>=1.7.1
#   Downloading proto_plus-1.22.1-py3-none-any.whl (47 kB)
#      |████████████████████████████████| 47 kB 223 kB/s
# Collecting cloudpickle<3,>=2.1.0
#   Downloading cloudpickle-2.2.0-py3-none-any.whl (25 kB)
# Requirement already satisfied: pydot<2,>=1.2.0 in /usr/local/lib/python3.7/dist-packages (from apache-beam->object-detection==0.1) (1.3.0)
# Collecting requests<3.0.0dev,>=2.18.0
#   Downloading requests-2.28.1-py3-none-any.whl (62 kB)
#      |████████████████████████████████| 62 kB 1.5 MB/s
# Requirement already satisfied: crcmod<2.0,>=1.7 in /usr/local/lib/python3.7/dist-packages (from apache-beam->object-detection==0.1) (1.7)
# Collecting orjson<4.0
#   Downloading orjson-3.8.0-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (270 kB)
#      |████████████████████████████████| 270 kB 71.1 MB/s
# Collecting docopt
#   Downloading docopt-0.6.2.tar.gz (25 kB)
# Collecting protobuf<4.0.0dev,>=3.12.0
#   Downloading protobuf-3.19.6-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.1 MB)
#      |████████████████████████████████| 1.1 MB 55.8 MB/s
# Requirement already satisfied: charset-normalizer<3,>=2 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0dev,>=2.18.0->google-api-core<3dev,>=1.21.0->google-api-python-client>=1.6.7->tf-models-official>=2.5.1->object-detection==0.1) (2.1.1)
# Requirement already satisfied: cycler>=0.10.0 in /usr/local/lib/python3.7/dist-packages (from lvis->object-detection==0.1) (0.11.0)
# Requirement already satisfied: opencv-python>=4.1.0.25 in /usr/local/lib/python3.7/dist-packages (from lvis->object-detection==0.1) (4.6.0.66)
# Requirement already satisfied: kiwisolver>=1.1.0 in /usr/local/lib/python3.7/dist-packages (from lvis->object-detection==0.1) (1.4.4)
# Requirement already satisfied: text-unidecode>=1.3 in /usr/local/lib/python3.7/dist-packages (from python-slugify->kaggle>=1.3.9->tf-models-official>=2.5.1->object-detection==0.1) (1.3)
# Requirement already satisfied: scikit-learn>=0.21.3 in /usr/local/lib/python3.7/dist-packages (from seqeval->tf-models-official>=2.5.1->object-detection==0.1) (1.0.2)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.7/dist-packages (from scikit-learn>=0.21.3->seqeval->tf-models-official>=2.5.1->object-detection==0.1) (1.2.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from scikit-learn>=0.21.3->seqeval->tf-models-official>=2.5.1->object-detection==0.1) (3.1.0)
# Requirement already satisfied: typeguard>=2.7 in /usr/local/lib/python3.7/dist-packages (from tensorflow-addons->tf-models-official>=2.5.1->object-detection==0.1) (2.7.1)
# Requirement already satisfied: promise in /usr/local/lib/python3.7/dist-packages (from tensorflow-datasets->tf-models-official>=2.5.1->object-detection==0.1) (2.3)
# Requirement already satisfied: importlib-resources in /usr/local/lib/python3.7/dist-packages (from tensorflow-datasets->tf-models-official>=2.5.1->object-detection==0.1) (5.10.0)
# Requirement already satisfied: tensorflow-metadata in /usr/local/lib/python3.7/dist-packages (from tensorflow-datasets->tf-models-official>=2.5.1->object-detection==0.1) (1.10.0)
# Requirement already satisfied: toml in /usr/local/lib/python3.7/dist-packages (from tensorflow-datasets->tf-models-official>=2.5.1->object-detection==0.1) (0.10.2)
# Requirement already satisfied: etils[epath] in /usr/local/lib/python3.7/dist-packages (from tensorflow-datasets->tf-models-official>=2.5.1->object-detection==0.1) (0.8.0)
# Building wheels for collected packages: object-detection, py-cpuinfo, dill, avro-python3, docopt, seqeval
#   Building wheel for object-detection (setup.py) ... done
#   Created wheel for object-detection: filename=object_detection-0.1-py3-none-any.whl size=1
efficientnet_model.py:143] round_filter input=1280 output=2304
# I1015 17:37:59.778732 139853904942976 efficientnet_model.py:453] Building model efficientnet with params ModelConfig(width_coefficient=1.8, depth_coefficient=2.6, resolution=528, dropout_rate=0.5, blocks=(BlockConfig(input_filters=32, output_filters=16, kernel_size=3, num_repeat=1, expand_ratio=1, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=16, output_filters=24, kernel_size=3, num_repeat=2, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=24, output_filters=40, kernel_size=5, num_repeat=2, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=40, output_filters=80, kernel_size=3, num_repeat=3, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=80, output_filters=112, kernel_size=5, num_repeat=3, expand_ratio=6, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=112, output_filters=192, kernel_size=5, num_repeat=4, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=192, output_filters=320, kernel_size=3, num_repeat=1, expand_ratio=6, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise')), stem_base_filters=32, top_base_filters=1280, activation='simple_swish', batch_norm='default', bn_momentum=0.99, bn_epsilon=0.001, weight_decay=5e-06, drop_connect_rate=0.2, depth_divisor=8, min_depth=None, use_se=True, input_channels=3, num_classes=1000, model_name='efficientnet', rescale_input=False, data_format='channels_last', dtype='float32')
# I1015 17:37:59.871255 139853904942976 ssd_efficientnet_bifpn_feature_extractor.py:146] EfficientDet EfficientNet backbone version: efficientnet-b7
# I1015 17:37:59.871406 139853904942976 ssd_efficientnet_bifpn_feature_extractor.py:147] EfficientDet BiFPN num filters: 384
# I1015 17:37:59.871485 139853904942976 ssd_efficientnet_bifpn_feature_extractor.py:149] EfficientDet BiFPN num iterations: 8
# I1015 17:37:59.873023 139853904942976 efficientnet_model.py:143] round_filter input=32 output=64
# I1015 17:37:59.891780 139853904942976 efficientnet_model.py:143] round_filter input=32 output=64
# I1015 17:37:59.891901 139853904942976 efficientnet_model.py:143] round_filter input=16 output=32
# I1015 17:38:00.169614 139853904942976 efficientnet_model.py:143] round_filter input=16 output=32
# I1015 17:38:00.169779 139853904942976 efficientnet_model.py:143] round_filter input=24 output=48
# I1015 17:38:00.974776 139853904942976 efficientnet_model.py:143] round_filter input=24 output=48
# I1015 17:38:00.974945 139853904942976 efficientnet_model.py:143] round_filter input=40 output=80
# I1015 17:38:01.553563 139853904942976 efficientnet_model.py:143] round_filter input=40 output=80
# I1015 17:38:01.553732 139853904942976 efficientnet_model.py:143] round_filter input=80 output=160
# I1015 17:38:02.433075 139853904942976 efficientnet_model.py:143] round_filter input=80 output=160
# I1015 17:38:02.433259 139853904942976 efficientnet_model.py:143] round_filter input=112 output=224
# I1015 17:38:03.302695 139853904942976 efficientnet_model.py:143] round_filter input=112 output=224
# I1015 17:38:03.302881 139853904942976 efficientnet_model.py:143] round_filter input=192 output=384
# I1015 17:38:04.418916 139853904942976 efficientnet_model.py:143] round_filter input=192 output=384
# I1015 17:38:04.419093 139853904942976 efficientnet_model.py:143] round_filter input=320 output=640
# I1015 17:38:04.778378 139853904942976 efficientnet_model.py:143] round_filter input=1280 output=2560
# I1015 17:38:04.821831 139853904942976 efficientnet_model.py:453] Building model efficientnet with params ModelConfig(width_coefficient=2.0, depth_coefficient=3.1, resolution=600, dropout_rate=0.5, blocks=(BlockConfig(input_filters=32, output_filters=16, kernel_size=3, num_repeat=1, expand_ratio=1, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=16, output_filters=24, kernel_size=3, num_repeat=2, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=24, output_filters=40, kernel_size=5, num_repeat=2, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=40, output_filters=80, kernel_size=3, num_repeat=3, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=80, output_filters=112, kernel_size=5, num_repeat=3, expand_ratio=6, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=112, output_filters=192, kernel_size=5, num_repeat=4, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=192, output_filters=320, kernel_size=3, num_repeat=1, expand_ratio=6, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise')), stem_base_filters=32, top_base_filters=1280, activation='simple_swish', batch_norm='default', bn_momentum=0.99, bn_epsilon=0.001, weight_decay=5e-06, drop_connect_rate=0.2, depth_divisor=8, min_depth=None, use_se=True, input_channels=3, num_classes=1000, model_name='efficientnet', rescale_input=False, data_format='channels_last', dtype='float32')
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_create_ssd_models_from_config): 28.94s
# I1015 17:38:04.931260 139853904942976 test_util.py:2461] time(__main__.ModelBuilderTF2Test.test_create_ssd_models_from_config): 28.94s
# [       OK ] ModelBuilderTF2Test.test_create_ssd_models_from_config
# [ RUN      ] ModelBuilderTF2Test.test_invalid_faster_rcnn_batchnorm_update
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_invalid_faster_rcnn_batchnorm_update): 0.0s
# I1015 17:38:04.957980 139853904942976 test_util.py:2461] time(__main__.ModelBuilderTF2Test.test_invalid_faster_rcnn_batchnorm_update): 0.0s
# [       OK ] ModelBuilderTF2Test.test_invalid_faster_rcnn_batchnorm_update
# [ RUN      ] ModelBuilderTF2Test.test_invalid_first_stage_nms_iou_threshold
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_invalid_first_stage_nms_iou_threshold): 0.0s
# I1015 17:38:04.959767 139853904942976 test_util.py:2461] time(__main__.ModelBuilderTF2Test.test_invalid_first_stage_nms_iou_threshold): 0.0s
# [       OK ] ModelBuilderTF2Test.test_invalid_first_stage_nms_iou_threshold
# [ RUN      ] ModelBuilderTF2Test.test_invalid_model_config_proto
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_invalid_model_config_proto): 0.0s
# I1015 17:38:04.960342 139853904942976 test_util.py:2461] time(__main__.ModelBuilderTF2Test.test_invalid_model_config_proto): 0.0s
# [       OK ] ModelBuilderTF2Test.test_invalid_model_config_proto
# [ RUN      ] ModelBuilderTF2Test.test_invalid_second_stage_batch_size
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_invalid_second_stage_batch_size): 0.0s
# I1015 17:38:04.961734 139853904942976 test_util.py:2461] time(__main__.ModelBuilderTF2Test.test_invalid_second_stage_batch_size): 0.0s
# [       OK ] ModelBuilderTF2Test.test_invalid_second_stage_batch_size
# [ RUN      ] ModelBuilderTF2Test.test_session
# [  SKIPPED ] ModelBuilderTF2Test.test_session
# [ RUN      ] ModelBuilderTF2Test.test_unknown_faster_rcnn_feature_extractor
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_unknown_faster_rcnn_feature_extractor): 0.0s
# I1015 17:38:04.963060 139853904942976 test_util.py:2461] time(__main__.ModelBuilderTF2Test.test_unknown_faster_rcnn_feature_extractor): 0.0s
# [       OK ] ModelBuilderTF2Test.test_unknown_faster_rcnn_feature_extractor
# [ RUN      ] ModelBuilderTF2Test.test_unknown_meta_architecture
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_unknown_meta_architecture): 0.0s
# I1015 17:38:04.963502 139853904942976 test_util.py:2461] time(__main__.ModelBuilderTF2Test.test_unknown_meta_architecture): 0.0s
# [       OK ] ModelBuilderTF2Test.test_unknown_meta_architecture
# [ RUN      ] ModelBuilderTF2Test.test_unknown_ssd_feature_extractor
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_unknown_ssd_feature_extractor): 0.0s
# I1015 17:38:04.964457 139853904942976 test_util.py:2461] time(__main__.ModelBuilderTF2Test.test_unknown_ssd_feature_extractor): 0.0s
# [       OK ] ModelBuilderTF2Test.test_unknown_ssd_feature_extractor
# ----------------------------------------------------------------------
# Ran 24 tests in 36.101s
#
# OK (skipped=1)

# %%
# if you don't see 'OK (skipped=1)' thing in above cell then you must be encountered with errors
# just simply uninstall and re-install packages which are shown in the errors

# pip uninstall protobuf matplotlib -y
# pip install protobuf matplotlib==3.2.2
#!pip install tensorflow-gpu --upgrade
#!pip uninstall protobuf matplotlib -y
#!pip install protobuf matplotlib
#!pip install Pillow
#!pip install pyyaml

# %%
#!pip list

# %%
import object_detection

# %%
if os.name =='posix':
    # !wget {PRETRAINED_MODEL_URL}
    # !mv {PRETRAINED_MODEL_NAME+'.tar.gz'} {paths['PRETRAINED_MODEL_PATH']}
    # !cd {paths['PRETRAINED_MODEL_PATH']} && tar -zxvf {PRETRAINED_MODEL_NAME+'.tar.gz'}
if os.name == 'nt':
    wget.download(PRETRAINED_MODEL_URL)
    # !move {PRETRAINED_MODEL_NAME+'.tar.gz'} {paths['PRETRAINED_MODEL_PATH']}
    # !cd {paths['PRETRAINED_MODEL_PATH']} && tar -zxvf {PRETRAINED_MODEL_NAME+'.tar.gz'}
# Out:
# --2022-10-15 04:30:07--  http://download.tensorflow.org/models/object_detection/tf2/20200711/ssd_resnet50_v1_fpn_640x640_coco17_tpu-8.tar.gz
# Resolving download.tensorflow.org (download.tensorflow.org)... 142.250.4.128, 2404:6800:4003:c06::80
# Connecting to download.tensorflow.org (download.tensorflow.org)|142.250.4.128|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 244817203 (233M) [application/x-tar]
# Saving to: ‘ssd_resnet50_v1_fpn_640x640_coco17_tpu-8.tar.gz’
#
# ssd_resnet50_v1_fpn 100%[===================>] 233.48M  53.8MB/s    in 4.3s
#
# 2022-10-15 04:30:13 (53.8 MB/s) - ‘ssd_resnet50_v1_fpn_640x640_coco17_tpu-8.tar.gz’ saved [244817203/244817203]
#
# ssd_resnet50_v1_fpn_640x640_coco17_tpu-8/
# ssd_resnet50_v1_fpn_640x640_coco17_tpu-8/checkpoint/
# ssd_resnet50_v1_fpn_640x640_coco17_tpu-8/checkpoint/ckpt-0.data-00000-of-00001
# ssd_resnet50_v1_fpn_640x640_coco17_tpu-8/checkpoint/checkpoint
# ssd_resnet50_v1_fpn_640x640_coco17_tpu-8/checkpoint/ckpt-0.index
# ssd_resnet50_v1_fpn_640x640_coco17_tpu-8/pipeline.config
# ssd_resnet50_v1_fpn_640x640_coco17_tpu-8/saved_model/
# ssd_resnet50_v1_fpn_640x640_coco17_tpu-8/saved_model/saved_model.pb
# ssd_resnet50_v1_fpn_640x640_coco17_tpu-8/saved_model/assets/
# ssd_resnet50_v1_fpn_640x640_coco17_tpu-8/saved_model/variables/
# ssd_resnet50_v1_fpn_640x640_coco17_tpu-8/saved_model/variables/variables.data-00000-of-00001
# ssd_resnet50_v1_fpn_640x640_coco17_tpu-8/saved_model/variables/variables.index

# %% [markdown]
# # 2. Create Label Map

# %%
labels = [{'name':'mask', 'id':1}, {'name':'no-mask', 'id':2}]

with open(files['LABELMAP'], 'w') as f:
    for label in labels:
        f.write('item { \n')
        f.write('\tname:\'{}\'\n'.format(label['name']))
        f.write('\tid:{}\n'.format(label['id']))
        f.write('}\n')

# %%
#pwd

# %%
#rm -rf /content/drive/MyDrive/TFOD/Tensorflow/workspace/images/train

# %% [markdown]
# # 3. Create TF records

# %%
# #OPTIONAL IF RUNNING ON COLAB
# ARCHIVE_FILES = os.path.join(paths['IMAGE_PATH'], 'archive.tar.gz')
# if os.path.exists(ARCHIVE_FILES):
#   !tar -zxvf {ARCHIVE_FILES}
# Out:
# dataset/train/
# dataset/train/-1x-1_jpg.rf.22b305fece3a347760bb3c41d38c233b.jpg
# dataset/train/-1x-1_jpg.rf.3068b9e8b2ad2a07aa26f023a5fda39f.jpg
# dataset/train/-1x-1_jpg.rf.7c8af5f94bfdaa85f2cb76ac9e65bcf8.jpg
# dataset/train/-I1-MS09uaqsLdGTFkgnS0Rcg1mmPyAj95ySg_eckoM_jpeg.rf
# dataset/test/1125506397_15801322206581n_jpg.rf.30d287b3dd354963f22e7d3a675dece5.jpg
# dataset/test/1196686205_jpg_14_jpg.rf.7fda6ab7449af4c26b0891b4bb39d04b.jpg
# dataset/test/1197315184_jpg_0_jpg.rf.cf4dcde8976593f3c8f54dd900bc6cd5.jpg
# dataset/test/1197620896_jpg.rf.a72fae286a0ca4454349a79bb416ac27.jpg
# dataset/test/1483800496-3386248642_jpg.rf.378ae40e8e18cbdf67c3c724e977d42a.jpg
# dataset/test/15150794626913_jpg.rf.4b3b760ca81bdf7228033d678a8b118c.jpg
# dataset/test/15391513321824spp815on8_jpg.rf.3dd0805d1438553eda957bc6d9326cbe.jpg
# dataset/test/phpM5suKS_jpg.rf.3874ac51cb6cc8093f6c793c68c132e8.jpg
# dataset/test/r1000019q669394n9qp_jpg.rf.c5e4e2e74d662afbddeea5098f4d50f0.jpg
# dataset/test/r1400018548960op29s_jpg.rf.63ac4d8dda45717fc0f770628b57e7a9.jpg
# dataset/test/REVZGCBIJNQPMIIXOKDCQA3GJI_jpg.rf.2f5a032dddd129d7c26ede644bc01af9.jpg
# dataset/test/S1-EV360_FACEMA_M_20200130144349_jpg.rf.7e34f97ccb3d1e5e3ff80108317284c3.jpg
# dataset/test/sdgdsgsg_jpg.rf.b16b17b692e4b4bb8df46548a9122c43.jpg
# dataset/test/shutterstock_1145933543-e1579497052960_jpg.rf.b9e4b07d9a2394891de56b44ac4fcded.jpg
# dataset/test/shutterstock_editorial_10536831j_2e16d0ba_fill-1200x650_jpg.rf.db9147c282d7c18f7f6e05f59ac8afca.jpg
# dataset/test/stock-photo-mother-and-her-daughter-walking-go-to-school-with-wearing-a-protection-mask-against-pm-air-1346870465_jpg.rf.a361edd8b08576e6bcd8c4d38a403d50.jpg
# dataset/test/test.csv
# dataset/test/us-state-department-warns-against-visiting-china-citing-coronavirus_jpg.rf.16aeb0ba43e4ffdea598de7b171d8e72.jpg
# dataset/test/w1240-p16x9-CORONAVIRUS-CHINA-HEALTH-APPLE-STORE_jpg.rf.ed3dcd851836164d734d899644d04282.jpg
# dataset/test/w1240-p16x9-coronavirus_CHINA-HEALTH_jpg.rf.8908f5e01f94029c4a9f910514c1415f.jpg

# %%
files['TF_RECORD_SCRIPT']
# Out:
# 'Tensorflow/scripts/CSV_generate_tfrecord.py'

# %%
if not os.path.exists(files['TF_RECORD_SCRIPT']):
    # !git clone https://github.com/mazqoty/GenerateTFRecord {paths['SCRIPTS_PATH']}
# Out:
# Cloning into 'Tensorflow/scripts'...
# remote: Enumerating objects: 13, done.
# remote: Counting objects: 100% (13/13), done.
# remote: Compressing objects: 100% (12/12), done.
# remote: Total 13 (delta 5), reused 0 (delta 0), pack-reused 0
# Unpacking objects: 100% (13/13), done.

# %%
#pwd

# %%
#os.path.join(paths['IMAGE_PATH'], 'train', 'train.csv')
files['TF_RECORD_SCRIPT']
# files['LABELMAP']
# os.path.join(paths['ANNOTATION_PATH'], 'train.record')
# Out:
# 'Tensorflow/scripts/CSV_generate_tfrecord.py'

# %%
# Create TFRecords from XML Files
# !python {files['TF_RECORD_SCRIPT']} -x {os.path.join(paths['IMAGE_PATH'], 'train')} -l {files['LABELMAP']} -o {os.path.join(paths['ANNOTATION_PATH'], 'train.record')} 
# !python {files['TF_RECORD_SCRIPT']} -x {os.path.join(paths['IMAGE_PATH'], 'test')} -l {files['LABELMAP']} -o {os.path.join(paths['ANNOTATION_PATH'], 'test.record')} 

# Create TFRecords from CSV Files
# !python {files['TF_RECORD_SCRIPT']} --csv_input={os.path.join(paths['IMAGE_PATH'], 'train', 'train.csv')} --image_dir={os.path.join(paths['IMAGE_PATH'], 'train')} --output_path={os.path.join(paths['ANNOTATION_PATH'], 'train.record')}
# !python {files['TF_RECORD_SCRIPT']} --csv_input={os.path.join(paths['IMAGE_PATH'], 'test', 'test.csv')} --image_dir={os.path.join(paths['IMAGE_PATH'], 'test')} --output_path={os.path.join(paths['ANNOTATION_PATH'], 'test.record')}
# Out:
# 2022-10-15 04:34:29.452458: E tensorflow/stream_executor/cuda/cuda_blas.cc:2981] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2022-10-15 04:34:30.145684: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer.so.7'; dlerror: libnvinfer.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/lib64-nvidia
# 2022-10-15 04:34:30.145797: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer_plugin.so.7'; dlerror: libnvinfer_plugin.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/lib64-nvidia
# 2022-10-15 04:34:30.145818: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Cannot dlopen some TensorRT libraries. If you would like to use Nvidia GPU with TensorRT, please make sure the missing libraries mentioned above are installed properly.
# Successfully created the TFRecords: /content/drive/MyDrive/TFOD/Tensorflow/workspace/annotations/train.record
# 2022-10-15 04:34:33.385611: E tensorflow/stream_executor/cuda/cuda_blas.cc:2981] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2022-10-15 04:34:34.089117: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer.so.7'; dlerror: libnvinfer.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/lib64-nvidia
# 2022-10-15 04:34:34.089221: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer_plugin.so.7'; dlerror: libnvinfer_plugin.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/lib64-nvidia
# 2022-10-15 04:34:34.089241: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Cannot dlopen some TensorRT libraries. If you would like to use Nvidia GPU with TensorRT, please make sure the missing libraries mentioned above are installed properly.
# Successfully created the TFRecords: /content/drive/MyDrive/TFOD/Tensorflow/workspace/annotations/test.record

# %% [markdown]
# # 4. Copy Model Config to Training Folder

# %%
if os.name =='posix':
    # !cp {os.path.join(paths['PRETRAINED_MODEL_PATH'], PRETRAINED_MODEL_NAME, 'pipeline.config')} {os.path.join(paths['CHECKPOINT_PATH'])}
if os.name == 'nt':
    # !copy {os.path.join(paths['PRETRAINED_MODEL_PATH'], PRETRAINED_MODEL_NAME, 'pipeline.config')} {os.path.join(paths['CHECKPOINT_PATH'])}

# %% [markdown]
# # 5. Update Config For Transfer Learning

# %%
import tensorflow as tf
from object_detection.utils import config_util
from object_detection.protos import pipeline_pb2
from google.protobuf import text_format

# %%
config = config_util.get_configs_from_pipeline_file(files['PIPELINE_CONFIG'])

# %%
config
# Out:
# {'model': ssd {
#    num_classes: 90
#    image_resizer {
#      fixed_shape_resizer {
#        height: 640
#        width: 640
#      }
#    }
#    feature_extractor {
#      type: "ssd_resnet50_v1_fpn_keras"
#      depth_multiplier: 1.0
#      min_depth: 16
#      conv_hyperparams {
#        regularizer {
#          l2_regularizer {
#            weight: 0.00039999998989515007
#          }
#        }
#        initializer {
#          truncated_normal_initializer {
#            mean: 0.0
#            stddev: 0.029999999329447746
#          }
#        }
#        activation: RELU_6
#        batch_norm {
#          decay: 0.996999979019165
#          scale: true
#          epsilon: 0.0010000000474974513
#        }
#      }
#      override_base_feature_extractor_hyperparams: true
#      fpn {
#        min_level: 3
#        max_level: 7
#      }
#    }
#    box_coder {
#      faster_rcnn_box_coder {
#        y_scale: 10.0
#        x_scale: 10.0
#        height_scale: 5.0
#        width_scale: 5.0
#      }
#    }
#    matcher {
#      argmax_matcher {
#        matched_threshold: 0.5
#        unmatched_threshold: 0.5
#        ignore_thresholds: false
#        negatives_lower_than_unmatched: true
#        force_match_for_each_row: true
#        use_matmul_gather: true
#      }
#    }
#    similarity_calculator {
#      iou_similarity {
#      }
#    }
#    box_predictor {
#      weight_shared_convolutional_box_predictor {
#        conv_hyperparams {
#          regularizer {
#            l2_regularizer {
#              weight: 0.00039999998989515007
#            }
#          }
#          initializer {
#            random_normal_initializer {
#              mean: 0.0
#              stddev: 0.009999999776482582
#            }
#          }
#          activation: RELU_6
#          batch_norm {
#            decay: 0.996999979019165
#            scale: true
#            epsilon: 0.0010000000474974513
#          }
#        }
#        depth: 256
#        num_layers_before_predictor: 4
#        kernel_size: 3
#        class_prediction_bias_init: -4.599999904632568
#      }
#    }
#    anchor_generator {
#      multiscale_anchor_generator {
#        min_level: 3
#        max_level: 7
#        anchor_scale: 4.0
#        aspect_ratios: 1.0
#        aspect_ratios: 2.0
#        aspect_ratios: 0.5
#        scales_per_octave: 2
#      }
#    }
#    post_processing {
#      batch_non_max_suppression {
#        score_threshold: 9.99999993922529e-09
#        iou_threshold: 0.6000000238418579
#        max_detections_per_class: 100
#        max_total_detections: 100
#        use_static_shapes: false
#      }
#      score_converter: SIGMOID
#    }
#    normalize_loss_by_num_matches: true
#    loss {
#      localization_loss {
#        weighted_smooth_l1 {
#        }
#      }
#      classification_loss {
#        weighted_sigmoid_focal {
#          gamma: 2.0
#          alpha: 0.25
#        }
#      }
#      classification_weight: 1.0
#      localization_weight: 1.0
#    }
#    encode_background_as_zeros: true
#    normalize_loc_loss_by_codesize: true
#    inplace_batchnorm_update: true
#    freeze_batchnorm: false
#  }, 'train_config': batch_size: 64
#  data_augmentation_options {
#    random_horizontal_flip {
#    }
#  }
#  data_augmentation_options {
#    random_crop_image {
#      min_object_covered: 0.0
#      min_aspect_ratio: 0.75
#      max_aspect_ratio: 3.0
#      min_area: 0.75
#      max_area: 1.0
#      overlap_thresh: 0.0
#    }
#  }
#  sync_replicas: true
#  optimizer {
#    momentum_optimizer {
#      learning_rate {
#        cosine_decay_learning_rate {
#          learning_rate_base: 0.03999999910593033
#          total_steps: 25000
#          warmup_learning_rate: 0.013333000242710114
#          warmup_steps: 2000
#        }
#      }
#      momentum_optimizer_value: 0.8999999761581421
#    }
#    use_moving_average: false
#  }
#  fine_tune_checkpoint: "PATH_TO_BE_CONFIGURED"
#  num_steps: 25000
#  startup_delay_steps: 0.0
#  replicas_to_aggregate: 8
#  max_number_of_boxes: 100
#  unpad_groundtruth_tensors: false
#  fine_tune_checkpoint_type: "classification"
#  use_bfloat16: true
#  fine_tune_checkpoint_version: V2, 'train_input_config': label_map_path: "PATH_TO_BE_CONFIGURED"
#  tf_record_input_reader {
#    input_path: "PATH_TO_BE_CONFIGURED"
#  }, 'eval_config': metrics_set: "coco_detection_metrics"
#  use_moving_averages: false, 'eval_input_configs': [label_map_path: "PATH_TO_BE_CONFIGURED"
#  shuffle: false
#  num_epochs: 1
#  tf_record_input_reader {
#    input_path: "PATH_TO_BE_CONFIGURED"
#  }
#  ], 'eval_input_config': label_map_path: "PATH_TO_BE_CONFIGURED"
#  shuffle: false
#  num_epochs: 1
#  tf_record_input_reader {
#    input_path: "PATH_TO_BE_CONFIGURED"
#  }}

# %%
pipeline_config = pipeline_pb2.TrainEvalPipelineConfig()
with tf.io.gfile.GFile(files['PIPELINE_CONFIG'], "r") as f:                                                                                                                                                                                                                     
    proto_str = f.read()                                                                                                                                                                                                                                          
    text_format.Merge(proto_str, pipeline_config)

# %%
pipeline_config.model.ssd.num_classes = len(labels)
pipeline_config.train_config.batch_size = 4
pipeline_config.train_config.fine_tune_checkpoint = os.path.join(paths['PRETRAINED_MODEL_PATH'], PRETRAINED_MODEL_NAME, 'checkpoint', 'ckpt-0')
pipeline_config.train_config.fine_tune_checkpoint_type = "detection"
pipeline_config.train_input_reader.label_map_path= files['LABELMAP']
pipeline_config.train_input_reader.tf_record_input_reader.input_path[:] = [os.path.join(paths['ANNOTATION_PATH'], 'train.record')]
pipeline_config.eval_input_reader[0].label_map_path = files['LABELMAP']
pipeline_config.eval_input_reader[0].tf_record_input_reader.input_path[:] = [os.path.join(paths['ANNOTATION_PATH'], 'test.record')]

# %%
files['PIPELINE_CONFIG']
# Out:
# 'Tensorflow/workspace/models/my_ssd_resnet50_v1_fpn_640x640/pipeline.config'

# %%
config_text = text_format.MessageToString(pipeline_config)                                                                                                                                                                                                        
with tf.io.gfile.GFile(files['PIPELINE_CONFIG'], "wb") as f:                                                                                                                                                                                                                     
    f.write(config_text)

# %% [markdown]
# # 6. Train the model

# %%
TRAINING_SCRIPT = os.path.join(paths['APIMODEL_PATH'], 'research', 'object_detection', 'model_main_tf2.py')

# %%
command = "python {} --model_dir={} --pipeline_config_path={} --num_train_steps=30000".format(TRAINING_SCRIPT, paths['CHECKPOINT_PATH'],files['PIPELINE_CONFIG'])

# %%
print(command)
# Out:
# python Tensorflow/models/research/object_detection/model_main_tf2.py --model_dir=Tensorflow/workspace/models/my_ssd_resnet50_v1_fpn_640x640 --pipeline_config_path=Tensorflow/workspace/models/my_ssd_resnet50_v1_fpn_640x640/pipeline.config --num_train_steps=30000

# %%
# !{command}
# Out:
# 2022-10-15 04:35:10.864747: E tensorflow/stream_executor/cuda/cuda_blas.cc:2981] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2022-10-15 04:35:11.667459: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer.so.7'; dlerror: libnvinfer.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/lib64-nvidia
# 2022-10-15 04:35:11.667594: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer_plugin.so.7'; dlerror: libnvinfer_plugin.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/lib64-nvidia
# 2022-10-15 04:35:11.667612: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Cannot dlopen some TensorRT libraries. If you would like to use Nvidia GPU with TensorRT, please make sure the missing libraries mentioned above are installed properly.
# 2022-10-15 04:35:14.816623: W tensorflow/core/common_runtime/gpu/gpu_bfc_allocator.cc:42] Overriding orig_value setting because the TF_FORCE_GPU_ALLOW_GROWTH environment variable is set. Original config value was 0.
# INFO:tensorflow:Using MirroredStrategy with devices ('/job:localhost/replica:0/task:0/device:GPU:0',)
# I1015 04:35:14.834863 140438086686592 mirrored_strategy.py:374] Using MirroredStrategy with devices ('/job:localhost/replica:0/task:0/device:GPU:0',)
# INFO:tensorflow:Maybe overwriting train_steps: 30000
# I1015 04:35:14.841814 140438086686592 config_util.py:552] Maybe overwriting train_steps: 30000
# INFO:tensorflow:Maybe overwriting use_bfloat16: False
# I1015 04:35:14.842020 140438086686592 config_util.py:552] Maybe overwriting use_bfloat16: False
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/object_detection/model_lib_v2.py:564: StrategyBase.experimental_distribute_datasets_from_function (from tensorflow.python.distribute.distribute_lib) is deprecated and will be removed in a future version.
# Instructions for updating:
# rename to distribute_datasets_from_function
# W1015 04:35:14.869182 140438086686592 deprecation.py:356] From /usr/local/lib/python3.7/dist-packages/object_detection/model_lib_v2.py:564: StrategyBase.experimental_distribute_datasets_from_function (from tensorflow.python.distribute.distribute_lib) is deprecated and will be removed in a future version.
# Instructions for updating:
# rename to distribute_datasets_from_function
# INFO:tensorflow:Reading unweighted datasets: ['Tensorflow/workspace/annotations/train.record']
# I1015 04:35:14.881368 140438086686592 dataset_builder.py:162] Reading unweighted datasets: ['Tensorflow/workspace/annotations/train.record']
# INFO:tensorflow:Reading record datasets for input file: ['Tensorflow/workspace/annotations/train.record']
# I1015 04:35:14.881758 140438086686592 dataset_builder.py:79] Reading record datasets for input file: ['Tensorflow/workspace/annotations/train.record']
# INFO:tensorflow:Number of filenames to read: 1
# I1015 04:35:14.881870 140438086686592 dataset_builder.py:80] Number of filenames to read: 1
# WARNING:tensorflow:num_readers has been reduced to 1 to match input file shards.
# W1015 04:35:14.881969 140438086686592 dataset_builder.py:87] num_readers has been reduced to 1 to match input file shards.
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/object_detection/builders/dataset_builder.py:104: parallel_interleave (from tensorflow.python.data.experimental.ops.interleave_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.data.Dataset.interleave(map_func, cycle_length, block_length, num_parallel_calls=tf.data.AUTOTUNE)` instead. If sloppy execution is desired, use `tf.data.Options.deterministic`.
# W1015 04:35:14.887844 140438086686592 deprecation.py:356] From /usr/local/lib/python3.7/dist-packages/object_detection/builders/dataset_builder.py:104: parallel_interleave (from tensorflow.python.data.experimental.ops.interleave_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.data.Dataset.interleave(map_func, cycle_length, block_length, num_parallel_calls=tf.data.AUTOTUNE)` instead. If sloppy execution is desired, use `tf.data.Options.deterministic`.
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/object_detection/builders/dataset_builder.py:236: DatasetV1.map_with_legacy_function (from tensorflow.python.data.ops.dataset_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.data.Dataset.map()
# W1015 04:35:14.903824 140438086686592 deprecation.py:356] From /usr/local/lib/python3.7/dist-packages/object_detection/builders/dataset_builder.py:236: DatasetV1.map_with_legacy_function (from tensorflow.python.data.ops.dataset_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.data.Dataset.map()
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/tensorflow/python/util/dispatch.py:1176: sparse_to_dense (from tensorflow.python.ops.sparse_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Create a `tf.sparse.SparseTensor` and use `tf.sparse.to_dense` instead.
# W1015 04:35:21.460101 140438086686592 deprecation.py:356] From /usr/local/lib/python3.7/dist-packages/tensorflow/python/util/dispatch.py:1176: sparse_to_dense (from tensorflow.python.ops.sparse_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Create a `tf.sparse.SparseTensor` and use `tf.sparse.to_dense` instead.
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/tensorflow/python/util/dispatch.py:1176: sample_distorted_bounding_box (from tensorflow.python.ops.image_ops_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# `seed2` arg is deprecated.Use sample_distorted_bounding_box_v2 instead.
# W1015 04:35:24.289226 140438086686592 deprecation.py:356] From /usr/local/lib/python3.7/dist-packages/tensorflow/python/util/dispatch.py:1176: sample_distorted_bounding_box (from tensorflow.python.ops.image_ops_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# `seed2` arg is deprecated.Use sample_distorted_bounding_box_v2 instead.
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/tensorflow/python/util/dispatch.py:1176: to_float (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.cast` instead.
# W1015 04:35:25.877829 140438086686592 deprecation.py:356] From /usr/local/lib/python3.7/dist-packages/tensorflow/python/util/dispatch.py:1176: to_float (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.cast` instead.
# /usr/local/lib/python3.7/dist-packages/keras/backend.py:452: UserWarning: `tf.keras.backend.set_learning_phase` is deprecated and will be removed after 2020-10-11. To update it, simply pass a True/False value to the `training` argument of the `__call__` method of your layer or model.
#   "`tf.keras.backend.set_learning_phase` is deprecated and "
# 2022-10-15 04:35:46.806009: W tensorflow/core/framework/cpu_allocator_impl.cc:82] Allocation of 20460000 exceeds 10% of free system memory.
# 2022-10-15 04:35:47.238324: W tensorflow/core/framework/cpu_allocator_impl.cc:82] Allocation of 20460000 exceeds 10% of free system memory.
# 2022-10-15 04:35:47.243644: W tensorflow/core/framework/cpu_allocator_impl.cc:82] Allocation of 20460000 exceeds 10% of free system memory.
# 2022-10-15 04:35:47.260459: W tensorflow/core/framework/cpu_allocator_impl.cc:82] Allocation of 20460000 exceeds 10% of free system memory.
# 2022-10-15 04:35:47.265554: W tensorflow/core/framework/cpu_allocator_impl.cc:82] Allocation of 20460000 exceeds 10% of free system memory.
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# I1015 04:35:59.655446 140438086686592 cross_device_ops.py:618] Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# I1015 04:35:59.659498 140438086686592 cross_device_ops.py:618] Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# I1015 04:35:59.663410 140438086686592 cross_device_ops.py:618] Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# I1015 04:35:59.664812 140438086686592 cross_device_ops.py:618] Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# I1015 04:35:59.668843 140438086686592 cross_device_ops.py:618] Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# I1015 04:35:59.670283 140438086686592 cross_device_ops.py:618] Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# I1015 04:35:59.675555 140438086686592 cross_device_ops.py:618] Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# I1015 04:35:59.676990 140438086686592 cross_device_ops.py:618] Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# I1015 04:35:59.679285 140438086686592 cross_device_ops.py:618] Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# I1015 04:35:59.680675 140438086686592 cross_device_ops.py:618] Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/tensorflow/python/util/deprecation.py:629: calling map_fn_v2 (from tensorflow.python.ops.map_fn) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Use fn_output_signature instead
# W1015 04:36:01.563808 140433636169472 deprecation.py:560] From /usr/local/lib/python3.7/dist-packages/tensorflow/python/util/deprecation.py:629: calling map_fn_v2 (from tensorflow.python.ops.map_fn) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Use fn_output_signature instead
# INFO:tensorflow:Step 100 per-step time 0.910s
# I1015 04:37:32.189059 140438086686592 model_lib_v2.py:707] Step 100 per-step time 0.910s
# INFO:tensorflow:{'Loss/classification_loss': 1.066367,
#  'Loss/localization_loss': 0.6153414,
#  'Loss/regularization_loss': 0.31315732,
#  'Loss/total_loss': 1.9948658,
#  'learning_rate': 0.014666351}
# I1015 04:37:32.189425 140438086686592 model_lib_v2.py:708] {'Loss/classification_loss': 1.066367,
#  'Loss/localization_loss': 0.6153414,
#  'Loss/regularization_loss': 0.31315732,
#  'Loss/total_loss': 1.9948658,
#  'learning_rate': 0.014666351}
# INFO:tensorflow:Step 200 per-step time 0.547s
# I1015 04:38:26.850986 140438086686592 model_lib_v2.py:707] Step 200 per-step time 0.547s
# INFO:tensorflow:{'Loss/classification_loss': 0.67723554,
#  'Loss/localization_loss': 0.5006249,
#  'Loss/regularization_loss': 0.31500146,
#  'Loss/total_loss': 1.492862,
#  'learning_rate': 0.0159997}
# I1015 04:38:26.851315 140438086686592 model_lib_v2.py:708] {'Loss/classification_loss': 0.67723554,
#  'Loss/localization_loss': 0.5006249,
#  'Loss/regularization_loss': 0.31500146,
#  'Loss/total_loss': 1.492862,
#  'learning_rate': 0.0159997}
# INFO:tensorflow:Step 300 per-step time 0.556s
# I1015 04:39:22.486497 140438086686592 model_lib_v2.py:707] Step 300 per-step time 0.556s
# INFO:tensorflow:{'Loss/classification_loss': 0.56075066,
#  'Loss/localization_loss': 0.35394615,
#  'Loss/regularization_loss': 0.31246603,
#  'Loss/total_loss': 1.2271628,
#  'learning_rate': 0.01733305}
# I1015 04:39:22.486821 140438086686592 model_lib_v2.py:708] {'Loss/classification_loss': 0.56075066,
#  'Loss/localization_loss': 0.35394615,
#  'Loss/regularization_loss': 0.31246603,
#  'Loss/total_loss': 1.2271628,
#  'learning_rate': 0.01733305}
# INFO:tensorflow:Step 400 per-step time 0.563s
# I1015 04:40:18.739839 140438086686592 model_lib_v2.py:707] Step 400 per-step time 0.563s
# INFO:tensorflow:{'Loss/classification_loss': 0.480048,
#  'Loss/localization_loss': 0.42115292,
#  'Loss/regularization_loss': 0.31044486,
#  'Loss/total_loss': 1.2116457,
#  'learning_rate': 0.0186664}
# I1015 04:40:18.740176 140438086686592 model_lib_v2.py:708] {'Loss/classification_loss': 0.480048,
#  'Loss/localization_loss': 0.42115292,
#  'Loss/regularization_loss': 0.31044486,
#  'Loss/total_loss': 1.2116457,
#  'learning_rate': 0.0186664}
# INFO:tensorflow:Step 500 per-step time 0.566s
# I1015 04:41:15.367776 140438086686592 model_lib_v2.py:707] Step 500 per-step time 0.566s
# INFO:tensorflow:{'Loss/classification_loss': 0.4894993,
#  'Loss/localization_loss': 0.3679271,
#  'Loss/regularization_loss': 0.30823487,
#  'Loss/total_loss': 1.1656613,
#  'learning_rate': 0.01999975}
# I1015 04:41:15.368167 140438086686592 model_lib_v2.py:708] {'Loss/classification_loss': 0.4894993,
#  'Loss/localization_loss': 0.3679271,
#  'Loss/regularization_loss': 0.30823487,
#  'Loss/total_loss': 1.1656613,
#  'learning_rate': 0.01999975}
# INFO:tensorflow:Step 600 per-step time 0.569s
# I1015 04:42:12.295661 140438086686592 model_lib_v2.py:707] Step 600 per-step time 0.569s
# INFO:tensorflow:{'Loss/classification_loss': 0.37927333,
#  'Loss/localization_loss': 0.28748807,
#  'Loss/regularization_loss': 0.30566058,
#  'Loss/total_loss': 0.972422,
#  'learning_rate': 0.0213331}
# I1015 04:42:12.295997 140438086686592 model_lib_v2.py:708] {'Loss/classification_loss': 0.37927333,
#  'Loss/localization_loss': 0.28748807,
#  'Loss/regularization_loss': 0.30566058,
#  'Loss/total_loss': 0.972422,
#  'learning_rate': 0.0213331}
# INFO:tensorflow:Step 700 per-step time 0.572s
# I1015 04:43:09.451756 140438086686592 model_lib_v2.py:707] Step 700 per-step time 0.572s
# INFO:tensorflow:{'Loss/classification_loss': 0.5379548,
#  'Loss/localization_loss': 0.29090503,
#  'Loss/regularization_loss': 0.30345288,
#  'Loss/total_loss': 1.1323127,
#  'learning_rate': 0.02266645}
# I1015 04:43:09.452112 140438086686592 model_lib_v2.py:708] {'Loss/classification_loss': 0.5379548,
#  'Loss/localization_loss': 0.29090503,
#  'Loss/regularization_loss': 0.30345288,
#  'Loss/total_loss': 1.1323127,
#  'learning_rate': 0.02266645}
# INFO:tensorflow:Step 800 per-step time 0.572s
# I1015 04:44:06.606424 140438086686592 model_lib_v2.py:707] Step 800 per-step time 0.572s
# INFO:tensorflow:{'Loss/classification_loss': 0.40379563,
#  'Loss/localization_loss': 0.28128764,
#  'Loss/regularization_loss': 0.3007574,
#  'Loss/total_loss': 0.9858407,
#  'learning_rate': 0.023999799}
# I1015 04:44:06.606729 140438086686592 model_lib_v2.py:708] {'Loss/classification_loss': 0.40379563,
#  'Loss/localization_loss': 0.28128764,
#  'Loss/regularization_loss': 0.3007574,
#  'Loss/total_loss': 0.9858407,
#  'learning_rate': 0.023999799}
# INFO:tensorflow:Step 900 per-step time 0.573s
# I1015 04:45:03.886577 140438086686592 model_lib_v2.py:707] Step 900 per-step time 0.573s
# INFO:tensorflow:{'Loss/classification_loss': 0.38724464,
#  'Loss/localization_loss': 0.27651116,
#  'Loss/regularization_loss': 0.2982527,
#  'Loss/total_loss': 0.9620085,
#  'learning_rate': 0.025333151}
# I1015 04:45:03.887001 140438086686592 model_lib_v2.py:708] {'Loss/classification_loss': 0.38724464,
#  'Loss/localization_loss': 0.27651116,
#  'Loss/regularization_loss': 0.2982527,
#  'Loss/total_loss': 0.9620085,
#  'learning_rate': 0.025333151}
# INFO:tensorflow:Step 1000 per-step time 0.573s
# I1015 04:46:01.156317 140438086686592 model_lib_v2.py:707] Step 1000 per-step time 0.573s
# INFO:tensorflow:{'Loss/classification_loss': 0.4123626,
#  'Loss/localization_loss': 0.2966642,
#  'Loss/regularization_loss': 0.29536024,
#  'Loss/total_loss': 1.004387,
#  'learning_rate': 0.0266665}
# I1015 04:46:01.156625 140438086686592 model_lib_v2.py:708] {'Loss/classification_loss': 0.4123626,
#  'Loss/localization_loss': 0.2966642,
#  'Loss/regularization_loss': 0.29536024,
#  'Loss/total_loss': 1.004387,
#  'learning_rate': 0.0266665}
# INFO:tensorflow:Step 1100 per-step time 0.597s
# I1015 04:47:00.850091 140438086686592 model_lib_v2.py:707] Step 1100 per-step time 0.597s
# INFO:tensorflow:{'Loss/classification_loss': 0.36630318,
#  'Loss/localization_loss': 0.17137161,
#  'Loss/regularization_loss': 0.29307142,
#  'Loss/total_loss': 0.8307462,
#  'learning_rate': 0.02799985}
# I1015 04:47:00.850435 140438086686592 model_lib_v2.py:708] {'Loss/classification_loss': 0.36630318,
#  'Loss/localization_loss': 0.17137161,
#  'Loss/regularization_loss': 0.29307142,
#  'Loss/total_loss': 0.8307462,
#  'learning_rate': 0.02799985}
# INFO:tensorflow:Step 1200 per-step time 0.573s
# I1015 04:47:58.196152 140438086686592 model_lib_v2.py:707] Step 1200 per-step time 0.573s
# INFO:tensorflow:{'Loss/classification_loss': 0.2911044,
#  'Loss/localization_loss': 0.16788422,
#  'Loss/regularization_loss': 0.29069474,
#  'Loss/total_loss': 0.7496834,
#  'learning_rate': 0.0293332}
# I1015 04:47:58.196467 140438086686592 model_lib_v2.py:708] {'Loss/classification_loss': 0.2911044,
#  'Loss/localization_loss': 0.16788422,
#  'Loss/regularization_loss': 0.29069474,
#  'Loss/total_loss': 0.7496834,
#  'learning_rate': 0.0293332}
# INFO:tensorflow:Step 1300 per-step time 0.573s
# I1015 04:48:55.517049 140438086686592 model_lib_v2.py:707] Step 1300 per-step time 0.573s
# INFO:tensorflow:{'Loss/classification_loss': 0.33212274,
#  'Loss/localization_loss': 0.22997712,
#  'Loss/regularization_loss': 0.2892322,
#  'Loss/total_loss': 0.85133207,
#  'learning_rate': 0.03066655}
# I1015 04:48:55.517388 140438086686592 model_lib_v2.py:708] {'Loss/classification_loss': 0.33212274,
#  'Loss/localization_loss': 0.22997712,
#  'Loss/regularization_loss': 0.2892322,
#  'Loss/total_loss': 0.85133207,
#  'learning_rate': 0.03066655}
# INFO:tensorflow:Step 1400 per-step time 0.574s
# I1015 04:49:52.894315 140438086686592 model_lib_v2.py:707] Step 1400 per-step time 0.574s
# INFO:tensorflow:{'Loss/classification_loss': 0.38829985,
#  'Loss/localization_loss': 0.2759191,
#  'Loss/regularization_loss': 0.28803787,
#  'Loss/total_loss': 0.9522568,
#  'learning_rate': 0.0319999}
# I1015 04:49:52.894623 140438086686592 model_lib_v2.py:708] {'Loss/classification_loss': 0.38829985,
#  'Loss/localization_loss': 0.2759191,
#  'Loss/regularization_loss': 0.28803787,
#  'Loss/total_loss': 0.9522568,
#  'learning_rate': 0.0319999}
# INFO:tensorflow:Step 1500 per-step time 0.574s
# I1015 04:50:50.279342 140438086686592 model_lib_v2.py:707] Step 1500 per-step time 0.574s
# INFO:tensorflow:{'Loss/classification_loss': 0.25967926,
#  'Loss/localization_loss': 0.18719149,
#  'Loss/regularization_loss': 0.28579226,
#  'Loss/total_loss': 0.73266304,
#  'learning_rate': 0.03333325}
# I1015 04:50:50.279685 140438086686592 model_lib_v2.py:708] {'Loss/classification_loss': 0.25967926,
#  'Loss/localization_loss': 0.18719149,
#  'Loss/regularization_loss': 0.28579226,
#  'Loss/total_loss': 0.73266304,
#  'learning_rate': 0.03333325}
# INFO:tensorflow:Step 1600 per-step time 0.574s
# I1015 04:51:47.644939 140438086686592 model_lib_v2.py:707] Step 1600 per-step time 0.574s
# INFO:tensorflow:{'Loss/classification_loss': 0.2934452,
#  'Loss/localization_loss': 0.16134404,
#  'Loss/regularization_loss': 0.28358677,
#  'Loss/total_loss': 0.738376,
#  'learning_rate': 0.034666598}
# I1015 04:51:47.645235 140438086686592 model_lib_v2.py:708] {'Loss/classification_loss': 0.2934452,
#  'Loss/localization_loss': 0.16134404,
#  'Loss/regularization_loss': 0.28358677,
#  'Loss/total_loss': 0.738376,
#  'learning_rate': 0.034666598}
# INFO:tensorflow:Step 1700 per-step time 0.574s
# I1015 04:52:45.046788 140438086686592 model_lib_v2.py:707] Step 1700 per-step time 0.574s
# INFO:tensorflow:{'Loss/classification_loss': 0.20992272,
#  'Loss/localization_loss': 0.12450564,
#  'Loss/regularization_loss': 0.28142697,
#  'Loss/total_loss': 0.61585534,
#  'learning_rate': 0.03599995}
# I1015 04:52:45.047139 140438086686592 model_lib_v2.py:708] {'Loss/classification_loss': 0.20992272,
#  'Loss/localization_loss': 0.12450564,
#  'Loss/regularization_loss': 0.28142697,
#  'Loss/total_loss': 0.61585534,
#  'learning_rate': 0.03599995}
# INFO:tensorflow:Step 1800 per-step time 0.574s
# I1015 04:53:42.416169 140438086686592 model_lib_v2.py:707] Step 1800 per-step time 0.574s
# INFO:tensorflow:{'Loss/classification_loss': 0.23103634,
#  'Loss/localization_loss': 0.15939856,
#  'Loss/regularization_loss': 0.27908313,
#  'Loss/total_loss': 0.669518,
#  'learning_rate': 0.037333302}
# I1015 04:53:42.416472 140438086686592 model_lib_v2.py:708] {'Loss/classification_loss': 0.23103634,
#  'Loss/localization_loss': 0.15939856,
#  'Loss/regularization_loss': 0.27908313,
#  'Loss/total_loss': 0.669518,
#  'learning_rate': 0.037333302}
# INFO:tensorflow:Step 1900 per-step time 0.574s
# I1015 04:54:39.817332 140438086686592 model_lib_v2.py:707] Step 1900 per-step time 0.574s
# INFO:tensorflow:{'Loss/classification_loss': 0.22544481,
#  'Loss/localization_loss': 0.17685264,
#  'Loss/regularization_loss': 0.2767569,
#  'Loss/total_loss': 0.6790544,
#  'learning_rate': 0.03866665}
# I1015 04:54:39.817728 140438086686592 model_lib_v2.py:708] {'Loss/classification_loss': 0.22544481,
#  'Loss/localization_loss': 0.17685264,
#  'Loss/regularization_loss': 0.2767569,
#  'Loss/total_loss': 0.6790544,
#  'learning_rate': 0.03866665}
# INFO:tensorflow:Step 2000 per-step time 0.574s
# I1015 04:55:37.192247 140438086686592 model_lib_v2.py:707] Step 2000 per-step time 0.574s
# INFO:tensorflow:{'Loss/classification_loss': 0.25477028,
#  'Loss/localization_loss': 0.19919696,
#  'Loss/regularization_loss': 0.27499345,
#  'Loss/total_loss': 0.7289607,
#  'learning_rate': 0.04}
# I1015 04:55:37.192549 140438086686592 model_lib_v2.py:708] {'Loss/classification_loss': 0.25477028,
#  'Loss/localization_loss': 0.19919696,
#  'Loss/regularization_loss': 0.27499345,
#  'Loss/total_loss': 0.7289607,
#  'learning_rate': 0.04}
# INFO:tensorflow:Step 2100 per-step time 0.595s
# I1015 04:56:36.660739 140438086686592 model_lib_v2.py:707] Step 2100 per-step time 0.595s
# INFO:tensorflow:{'Loss/classification_loss': 4.0505204,
#  'Loss/localization_loss': 0.67505884,
#  'Loss/regularization_loss': 4.8452682,
#  'Loss/total_loss': 9.5708475,
#  'learning_rate': 0.039998136}
# I1015 04:56:36.661079 140438086686592 model_lib_v2.py:708] {'Loss/classification_loss': 4.0505204,
#  'Loss/localization_loss': 0.67505884,
#  'Loss/regularization_loss': 4.8452682,
#  'Loss/total_loss': 9.5708475,
#  'learning_rate': 0.039998136}
# INFO:tensorflow:Step 2200 per-step time 0.567s
# I1015 04:57:33.395591 140438086686592 model_lib_v2.py:707] Step 2200 per-step time 0.567s
# INFO:tensorflow:{'Loss/classification_loss': 0.71752644,
#  'Loss/localization_loss': 0.58887166,
#  'Loss/regularization_loss': 11.160311,
#  'Loss/total_loss': 12.466709,
#  'learning_rate': 0.039992537}
# I1015 04:57:33.395900 140438086686592 model_lib_v2.py:708] {'Loss/classification_loss': 0.71752644,
#  'Loss/localization_loss': 0.58887166,
#  'Loss/regularization_loss': 11.160311,
#  'Loss/total_loss': 12.466709,
#  'learning_rate': 0.039992537}
# INFO:tensorflow:Step 2300 per-step time 0.568s
# I1015 04:58:30.195062 140438086686592 model_lib_v2.py:707] Step 2300 per-step time 0.568s
# INFO:tensorflow:{'Loss/classification_loss': 1.0334846,
#  'Loss/localization_loss': 0.4423143,
#  'Loss/regularization_loss': 10.8099575,
#  'Loss/total_loss': 12.285756,
#  'learning_rate': 0.03998321}
# I1015 04:58:30.195392 140438086686592 model_lib_v2.py:708] {'Loss/classification_loss': 1.0334846,
#  'Loss/localization_loss': 0.4423143,
#  'Loss/regularization_loss': 10.8099575,
#  'Loss/total_loss': 12.285756,
#  'learning_rate': 0.03998321}
# INFO:tensorflow:Step 2400 per-step time 0.566s
# I1015 04:59:26.821418 140438086686592 model_lib_v2.py:707] Step 2400 per-step time 0.566s
# INFO:tensorflow:{'Loss/classification_loss': 0.80608845,
#  'Loss/localization_loss': 0.50072443,
#  'Loss/regularization_loss': 10.47182,
#  'Loss/total_loss': 11.778633,
#  'learning_rate': 0.039970152}
# I1015 04:59:26.821726 140438086686592 model_lib_v2.py:708] {'Loss/classification_loss': 0.80608845,
#  'Loss/localization_loss': 0.50072443,
#  'Loss/regularization_loss': 10.47182,
#  'Loss/total_loss': 11.778633,
#  'learning_rate': 0.039970152}
# INFO:tensorflow:Step 2500 per-step time 0.568s
# I1015 05:00:23.651462 140438086686592 model_lib_v2.py:707] Step 2500 per-step time 0.568s
# INFO:tensorflow:{'Loss/classification_loss': 0.6271142,
#  'Loss/localization_loss': 0.44932377,
#  'Loss/regularization_loss': 10.1426525,
#  'Loss/total_loss': 11.21909,
#  'learning_rate': 0.039953373}
# I1015 05:00:23.651781 140438086686592 model_lib_v2.py:708] {'Loss/classification_loss': 0.6271142,
#  'Loss/localization_loss': 0.44932377,
#  'Loss/regularization_loss': 10.1426525,
#  'Loss/total_loss': 11.21909,
#  'learning_rate': 0.039953373}
# INFO:tensorflow:Step 2600 per-step time 0.567s
# I1015 05:01:20.362617 140438086686592 model_lib_v2.py:707] Step 2600 per-step time 0.567s
# INFO:tensorflow:{'Loss/classification_loss': 0.52606684,
#  'Loss/localization_loss': 0.42801502,
#  'Loss/regularization_loss': 9.825474,
#  'Loss/total_loss': 10.779555,
#  'learning_rate': 0.03993287}
# I1015 05:01:20.362942 140438086686592 model_lib_v2.py:708] {'Loss/classification_loss': 0.52606684,
#  'Loss/localization_loss': 0.42801502,
#  'Loss/regularization_loss': 9.825474,
#  'Loss/total_loss': 10.779555,
#  'learning_rate': 0.03993287}
# INFO:tensorflow:Step 2700 per-step time 0.569s
# I1015 05:02:17.242192 140438086686592 model_lib_v2.py:707] Step 2700 per-step time 0.569s
# INFO:tensorflow:{'Loss/classification_loss': 0.73603535,
#  'Loss/localization_loss': 0.46775675,
#  'Loss/regularization_loss': 9.519413,
#  'Loss/total_loss': 10.723206,
#  'learning_rate': 0.039908648}
# I1015 05:02:17.242535 140438086686592 model_lib_v2.py:708] {'Loss/classification_loss': 0.73603535,
#  'Loss/localization_loss': 0.46775675,
#  'Loss/regularization_loss': 9.519413,
#  'Loss/total_loss': 10.723206,
#  'learning_rate': 0.039908648}
# INFO:tensorflow:Step 2800 per-step time 0.568s
# I1015 05:03:14.061139 140438086686592 model_lib_v2.py:707] Step 2800 per-step time 0.568s
# INFO:tensorflow:{'Loss/classification_loss': 0.49850082,
#  'Loss/localization_loss': 0.3390949,
#  'Loss/regularization_loss': 9.22134,
#  'Loss/total_loss': 10.058936,
#  'learning_rate': 0.039880715}
# I1015 05:03:14.061533 140438086686592 model_lib_v2.py:708] {'Loss/classification_loss': 0.49850082,
#  'Loss/localization_loss': 0.3390949,
#  'Loss/regularization_loss': 9.22134,
#  'Loss/total_loss': 10.058936,
#  'learning_rate': 0.039880715}
# INFO:tensorflow:Step 2900 per-step time 0.568s
# I1015 05:04:10.827289 140438086686592 model_lib_v2.py:707] Step 2900 per-step time 0.568s
# INFO:tensorflow:{'Loss/classification_loss': 0.6288773,
#  'Loss/localization_loss': 0.4985613,
#  'Loss/regularization_loss': 8.93302,
#  'Loss/total_loss': 10.060458,
#  'learning_rate': 0.039849065}
# I1015 05:04:10.827626 140438086686592 model_lib_v2.py:708] {'Loss/classification_loss': 0.6288773,
#  'Loss/localization_loss': 0.4985613,
#  'Loss/regularization_loss': 8.93302,
#  'Loss/total_loss': 10.060458,
#  'learning_rate': 0.039849065}
# INFO:tensorflow:Step 3000 per-step time 0.567s
# I1015 05:05:07.565211 140438086686592 model_lib_v2.py:707] Step 3000 per-step time 0.567s
# INFO:tensorflow:{'Loss/classification_loss': 0.55328476,
#  'Loss/localization_loss': 0.4413505,
#  'Loss/regularization_loss': 8.654612,
#  'Loss/total_loss': 9.649247,
#  'learning_rate': 0.03981372}
# I1015 05:05:07.565538 140438086686592 model_lib_v2.py:708] {'Loss/classification_loss': 0.55328476,
#  'Loss/localization_loss': 0.4413505,
#  'Loss/regularization_loss': 8.654612,
#  'Loss/total_loss': 9.649247,
#  'learning_rate': 0.03981372}
# INFO:tensorflow:Step 3100 per-step time 0.587s
# I1015 05:06:06.264587 140438086686592 model_lib_v2.py:707] Step 3100 per-step time 0.587s
# INFO:tensorflow:{'Loss/classification_loss': 0.66165656,
#  'Loss/localization_loss': 0.39144108,
#  'Loss/regularization_loss': 8.385275,
#  'Loss/total_loss': 9.438373,
#  'learning_rate': 0.03977467}
# I1015 05:06:06.264896 140438086686592 model_lib_v2.py:708] {'Loss/classification_loss': 0.66165656,
#  'Loss/localization_loss': 0.39144108,
#  'Loss/regularization_loss': 8.385275,
#  'Loss/total_loss': 9.438373,
#  'learning_rate': 0.03977467}
# INFO:tensorflow:Step 3200 per-step time 0.568s
# I1015 05:07:03.113298 140438086686592 model_lib_v2.py:707] Step 3200 per-step time 0.568s
# INFO:tensorflow:{'Loss/classification_loss': 0.6031085,
#  'Loss/localization_loss': 0.4436309,
#  'Loss/regularization_loss': 8.125152,
#  'Loss/total_loss': 9.171891,
#  'learning_rate': 0.03973194}
# I1015 05:07:03.113623 140438086686592 model_lib_v2.py:708] {'Loss/classification_loss': 0.6031085,
#  'Loss/localization_loss': 0.4436309,
#  'Loss/regularization_loss': 8.125152,
#  'Loss/total_loss': 9.171891,
#  'learning_rate': 0.03973194}
# INFO:tensorflow:Step 3300 per-step time 0.568s
# I1015 05:07:59.904258 140438086686592 model_lib_v2.py:707] Step 3300 per-step time 0.568s
# INFO:tensorflow:{'Loss/classification_loss': 0.45174885,
#  'Loss/localization_loss': 0.3340216,
#  'Loss/regularization_loss': 7.8727794,
#  'Loss/total_loss': 8.65855,
#  'learning_rate': 0.03968552}
# I1015 05:07:59.904570 140438086686592 model_lib_v2.py:708] {'Loss/classification_loss': 0.45174885,
#  'Loss/localization_loss': 0.3340216,
#  'Loss/regularization_loss': 7.8727794,
#  'Loss/total_loss': 8.65855,
#  'learning_rate': 0.03968552}
# INFO:tensorflow:Step 3400 per-step time 0.568s
# I1015 05:08:56.700515 140438086686592 model_lib_v2.py:707] Step 3400 per-step time 0.568s
# INFO:tensorflow:{'Loss/classification_loss': 0.5337702,
#  'Loss/localization_loss': 0.370869,
#  'Loss/regularization_loss': 7.628929,
#  'Loss/total_loss': 8.533568,
#  'learning_rate': 0.039635435}
# I1015 05:08:56.700839 140438086686592 model_lib_v2.py:708] {'Loss/classification_loss': 0.5337702,
#  'Loss/localization_loss': 0.370869,
#  'Loss/regularization_loss': 7.628929,
#  'Loss/total_loss': 8.533568,
#  'learning_rate': 0.039635435}
# INFO:tensorflow:Step 3500 per-step time 0.568s
# I1015 05:09:53.516199 140438086686592 model_lib_v2.py:707] Step 3500 per-step time 0.568s
# INFO:tensorflow:{'Loss/classification_loss': 0.50146097,
#  'Loss/localization_loss': 0.25410488,
#  'Loss/regularization_loss': 7.392828,
#  'Loss/total_loss': 8.148394,
#  'learning_rate': 0.03958168}
# I1015 05:09:53.516497 140438086686592 model_lib_v2.py:708] {'Loss/classification_loss': 0.50146097,
#  'Loss/localization_loss': 0.25410488,
#  'Loss/regularization_loss': 7.392828,
#  'Loss/total_loss': 8.148394,
#  'learning_rate': 0.03958168}
# INFO:tensorflow:Step 3600 per-step time 0.569s
# I1015 05:10:50.389305 140438086686592 model_lib_v2.py:707] Step 3600 per-step time 0.569s
# INFO:tensorflow:{'Loss/classification_loss': 0.51238364,
#  'Loss/localization_loss': 0.4099766,
#  'Loss/regularization_loss': 7.165137,
#  'Loss/total_loss': 8.087497,
#  'learning_rate': 0.039524276}
# I1015 05:10:50.389640 140438086686592 model_lib_v2.py:708] {'Loss/classification_loss': 0.51238364,
#  'Loss/localization_loss': 0.4099766,
#  'Loss/regularization_loss': 7.165137,
#  'Loss/total_loss': 8.087497,
#  'learning_rate': 0.039524276}
# INFO:tensorflow:Step 3700 per-step time 0.569s
# I1015 05:11:47.274452 140438086686592 model_lib_v2.py:707] Step 3700 per-step time 0.569s
# INFO:tensorflow:{'Loss/classification_loss': 0.48852777,
#  'Loss/localization_loss': 0.4022685,
#  'Loss/regularization_loss': 6.944048,
#  'Loss/total_loss': 7.834844,
#  'learning_rate': 0.03946323}
# I1015 05:11:47.274764 140438086686592 model_lib_v2.py:708] {'Loss/classification_loss': 0.48852777,
#  'Loss/localization_loss': 0.4022685,
#  'Loss/regularization_loss': 6.944048,
#  'Loss/total_loss': 7.834844,
#  'learning_rate': 0.03946323}
# INFO:tensorflow:Step 3800 per-step time 0.568s
# I1015 05:12:44.107607 140438086686592 model_lib_v2.py:707] Step 3800 per-step time 0.568s
# INFO:tensorflow:{'Loss/classification_loss': 0.5797063,
#  'Loss/localization_loss': 0.3431015,
#  'Loss/regularization_loss': 6.730496,
#  'Loss/total_loss': 7.6533036,
#  'learning_rate': 0.039398547}
# I1015 05:12:44.107998 140438086686592 model_lib_v2.py:708] {'Loss/classification_loss': 0.5797063,
#  'Loss/localization_loss': 0.3431015,
#  'Loss/regularization_loss': 6.730496,
#  'Loss/total_loss': 7.6533036,
#  'learning_rate': 0.039398547}
# INFO:tensorflow:Step 3900 per-step time 0.569s
# I1015 05:13:41.031990 140438086686592 model_lib_v2.py:707] Step 3900 per-step time 0.569s
# INFO:tensorflow:{'Loss/classification_loss': 0.40693218,
#  'Loss/localization_loss': 0.26133713,
#  'Loss/regularization_loss': 6.5241218,
#  'Loss/total_loss': 7.192391,
#  'learning_rate': 0.039330248}
# I1015 05:13:41.032279 140438086686592 model_lib_v2.py:708] {'Loss/classification_loss': 0.40693218,
#  'Loss/localization_loss': 0.26133713,
#  'Loss/regularization_loss': 6.5241218,
#  'Loss/total_loss': 7.192391,
#  'learning_rate': 0.039330248}
# INFO:tensorflow:Step 4000 per-step time 0.568s
# I1015 05:14:37.874671 140438086686592 model_lib_v2.py:707] Step 4000 per-step time 0.568s
# INFO:tensorflow:{'Loss/classification_loss': 0.5135222,
#  'Loss/localization_loss': 0.39489517,
#  'Loss/regularization_loss': 6.3243737,
#  'Loss/total_loss': 7.232791,
#  'learning_rate': 0.039258346}
# I1015 05:14:37.875012 140438086686592 model_lib_v2.py:708] {'Loss/classification_loss': 0.5135222,
#  'Loss/localization_loss': 0.39489517,
#  'Loss/regularization_loss': 6.3243737,
#  'Loss/total_loss': 7.232791,
#  'learning_rate': 0.039258346}
# INFO:tensorflow:Step 4100 per-step time 0.592s
# I1015 05:15:37.059444 140438086686592 model_lib_v2.py:707] Step 4100 per-step time 0.592s
# INFO:tensorflow:{'Loss/classification_loss': 0.40264836,
#  'Loss/localization_loss': 0.31157547,
#  'Loss/regularization_loss': 6.131425,
#  'Loss/total_loss': 6.845649,
#  'learning_rate': 0.03918285}
# I1015 05:15:37.059755 140438086686592 model_lib_v2.py:708] {'Loss/classification_loss': 0.40264836,
#  'Loss/localization_loss': 0.31157547,
#  'Loss/regularization_loss': 6.131425,
#  'Loss/total_loss': 6.845649,
#  'learning_rate': 0.03918285}
# INFO:tensorflow:Step 4200 per-step time 0.568s
# I1015 05:16:33.898970 140438086686592 model_lib_v2.py:707] Step 4200 per-step time 0.568s
# INFO:tensorflow:{'Loss/classification_loss': 0.4231424,
#  'Loss/localization_loss': 0.3474623,
#  'Loss/regularization_loss': 5.944805,
#  'Loss/total_loss': 6.7154098,
#  'learning_rate': 0.03910377}
# I1015 05:16:33.899316 140438086686592 model_lib_v2.py:708] {'Loss/classification_loss': 0.4231424,
#  'Loss/localization_loss': 0.3474623,
#  'Loss/regularization_loss': 5.944805,
#  'Loss/total_loss': 6.7154098,
#  'learning_rate': 0.03910377}
# INFO:tensorflow:Step 4300 per-step time 0.568s
# I1015 05:17:30.737730 140438086686592 model_lib_v2.py:707] Step 4300 per-step time 0.568s
# INFO:tensorflow:{'Loss/classification_loss': 0.39348075,
#  'Loss/localization_loss': 0.2989124,
#  'Loss/regularization_loss': 5.764625,
#  'Loss/total_loss': 6.4570184,
#  'learning_rate': 0.039021127}
# I1015 05:17:30.738034 140438086686592 model_lib_v2.py:708] {'Loss/classification_loss': 0.39348075,
#  'Loss/localization_loss': 0.2989124,
#  'Loss/regularization_loss': 5.764625,
#  'Loss/total_loss': 6.4570184,
#  'learning_rate': 0.039021127}
# INFO:tensorflow:Step 4400 per-step time 0.570s
# I1015 05:18:27.729943 140438086686592 model_lib_v2.py:707] Step 4400 per-step time 0.570s
# INFO:tensorflow:{'Loss/classification_loss': 0.43024784,
#  'Loss/localization_loss': 0.24828611,
#  'Loss/regularization_loss': 5.5900283,
#  'Loss/total_loss': 6.2685623,
#  'learning_rate': 0.03893494}
# I1015 05:18:27.730254 140438086686592 model_lib_v2.py:708] {'Loss/classification_loss': 0.43024784,
#  'Loss/localization_loss': 0.24828611,
#  'Loss/regularization_loss': 5.5900283,
#  'Loss/total_loss': 6.2685623,
#  'learning_rate': 0.03893494}
# INFO:tensorflow:Step 4500 per-step time 0.570s
# I1015 05:19:24.709957 140438086686592 model_lib_v2.py:707] Step 4500 per-step time 0.570s
# INFO:tensorflow:{'Loss/classification_loss': 0.36619157,
#  'Loss/localization_loss': 0.28482586,
#  'Loss/regularization_loss': 5.421606,
#  'Loss/total_loss': 6.0726233,
#  'learning_rate': 0.03884522}
# I1015 05:19:24.710308 140438086686592 model_lib_v2.py:708] {'Loss/classification_loss': 0.36619157,
#  'Loss/localization_loss': 0.28482586,
#  'Loss/regularization_loss': 5.421606,
#  'Loss/total_loss': 6.0726233,
#  'learning_rate': 0.03884522}
# INFO:tensorflow:Step 4600 per-step time 0.569s
# I1015 05:20:21.607736 140438086686592 model_lib_v2.py:707] Step 4600 per-step time 0.569s
# INFO:tensorflow:{'Loss/classification_loss': 0.3560626,
#  'Loss/localization_loss': 0.32937852,
#  'Loss/regularization_loss': 5.2584686,
#  'Loss/total_loss': 5.9439096,
#  'learning_rate': 0.03875198}
# I1015 05:20:21.608054 140438086686592 model_lib_v2.py:708] {'Loss/classification_loss': 0.3560626,
#  'Loss/localization_loss': 0.32937852,
#  'Loss/regularization_loss': 5.2584686,
#  'Loss/total_loss': 5.9439096,
#  'learning_rate': 0.03875198}
# INFO:tensorflow:Step 4700 per-step time 0.570s
# I1015 05:21:18.651591 140438086686592 model_lib_v2.py:707] Step 4700 per-step time 0.570s
# INFO:tensorflow:{'Loss/classification_loss': 0.4090331,
#  'Loss/localization_loss': 0.24687113,
#  'Loss/regularization_loss': 5.101178,
#  'Loss/total_loss': 5.7570825,
#  'learning_rate': 0.038655244}
# I1015 05:21:18.651947 140438086686592 model_lib_v2.py:708] {'Loss/classification_loss': 0.4090331,
#  'Loss/localization_loss': 0.24687113,
#  'Loss/regularization_loss': 5.101178,
#  'Loss/total_loss': 5.7570825,
#  'learning_rate': 0.038655244}
# INFO:tensorflow:Step 4800 per-step time 0.569s
# I1015 05:22:15.558854 140438086686592 model_lib_v2.py:707] Step 4800 per-step time 0.569s
# INFO:tensorflow:{'Loss/classification_loss': 0.3915303,
#  'Loss/localization_loss': 0.22417554,
#  'Loss/regularization_loss': 4.9485927,
#  'Loss/total_loss': 5.5642986,
#  'learning_rate': 0.038555026}
# I1015 05:22:15.559275 140438086686592 model_lib_v2.py:708] {'Loss/classification_loss': 0.3915303,
#  'Loss/localization_loss': 0.22417554,
#  'Loss/regularization_loss': 4.9485927,
#  'Loss/total_loss': 5.5642986,
#  'learning_rate': 0.038555026}
# INFO:tensorflow:Step 4900 per-step time 0.570s
# I1015 05:23:12.512956 140438086686592 model_lib_v2.py:707] Step 4900 per-step time 0.570s
# INFO:tensorflow:{'Loss/classification_loss': 0.3158141,
#  'Loss/localization_loss': 0.26657623,
#  'Loss/regularization_loss': 4.801443,
#  'Loss/total_loss': 5.3838334,
#  'learning_rate': 0.038451348}
# I1015 05:23:12.513264 140438086686592 model_lib_v2.py:708] {'Loss/classification_loss': 0.3158141,
#  'Loss/localization_loss': 0.26657623,
#  'Loss/regularization_loss': 4.801443,
#  'Loss/total_loss': 5.3838334,
#  'learning_rate': 0.038451348}
# INFO:tensorflow:Step 5000 per-step time 0.570s
# I1015 05:24:09.460265 140438086686592 model_lib_v2.py:707] Step 5000 per-step time 0.570s
# INFO:tensorflow:{'Loss/classification_loss': 0.4833538,
#  'Loss/localization_loss': 0.33572987,
#  'Loss/regularization_loss': 4.658907,
#  'Loss/total_loss': 5.4779906,
#  'learning_rate': 0.038344227}
# I1015 05:24:09.460568 140438086686592 model_lib_v2.py:708] {'Loss/classification_loss': 0.4833538,
#  'Loss/localization_loss': 0.33572987,
#  'Loss/regularization_loss': 4.658907,
#  'Loss/total_loss': 5.4779906,
#  'learning_rate': 0.038344227}
# INFO:tensorflow:Step 5100 per-step time 0.589s
# I1015 05:25:08.331233 140438086686592 model_lib_v2.py:707] Step 5100 per-step time 0.589s
# INFO:tensorflow:{'Loss/classification_loss': 0.37421066,
#  'Loss/localization_loss': 0.20134427,
#  'Loss/regularization_loss': 4.5214033,
#  'Loss/total_loss': 5.096958,
#  'learning_rate': 0.03823368}
# I1015 05:25:08.331567 140438086686592 model_lib_v2.py:708] {'Loss/classification_loss': 0.37421066,
#  'Loss/localization_loss': 0.20134427,
#  'Loss/regularization_loss': 4.5214033,
#  'Loss/total_loss': 5.096958,
#  'learning_rate': 0.03823368}
# INFO:tensorflow:Step 5200 per-step time 0.570s
# I1015 05:26:05.290055 140438086686592 model_lib_v2.py:707] Step 5200 per-step time 0.570s
# INFO:tensorflow:{'Loss/classification_loss': 0.31811824,
#  'Loss/localization_loss': 0.19360058,
#  'Loss/regularization_loss': 4.3879437,
#  'Loss/total_loss': 4.8996625,
#  'learning_rate': 0.038119733}
# I1015 05:26:05.290389 140438086686592 model_lib_v2.py:708] {'Loss/classification_loss': 0.31811824,
#  'Loss/localization_loss': 0.19360058,
#  'Loss/regularization_loss': 4.3879437,
#  'Loss/total_loss': 4.8996625,
#  'learning_rate': 0.038119733}
# INFO:tensorflow:Step 5300 per-step time 0.569s
# I1015 05:27:02.217099 140438086686592 model_lib_v2.py:707] Step 5300 per-step time 0.569s
# INFO:tensorflow:{'Loss/classification_loss': 0.35730737,
#  'Loss/localization_loss': 0.28184515,
#  'Loss/regularization_loss': 4.259469,
#  'Loss/total_loss': 4.8986216,
#  'learning_rate': 0.03800241}
# I1015 05:27:02.217422 140438086686592 model_lib_v2.py:708] {'Loss/classification_loss': 0.35730737,
#  'Loss/localization_loss': 0.28184515,
#  'Loss/regularization_loss': 4.259469,
#  'Loss/total_loss': 4.8986216,
#  'learning_rate': 0.03800241}
# INFO:tensorflow:Step 5400 per-step time 0.569s
# I1015 05:27:59.126450 140438086686592 model_lib_v2.py:707] Step 5400 per-step time 0.569s
# INFO:tensorflow:{'Loss/classification_loss': 0.52228934,
#  'Loss/localization_loss': 0.254621,
#  'Loss/regularization_loss': 4.1347246,
#  'Loss/total_loss': 4.911635,
#  'learning_rate': 0.037881725}
# I1015 05:27:59.126757 140438086686592 model_lib_v2.py:708] {'Loss/classification_loss': 0.52228934,
#  'Loss/localization_loss': 0.254621,
#  'Loss/regularization_loss': 4.1347246,
#  'Loss/total_loss': 4.911635,
#  'learning_rate': 0.037881725}
# INFO:tensorflow:Step 5500 per-step time 0.569s
# I1015 05:28:55.995793 140438086686592 model_lib_v2.py:707] Step 5500 per-step time 0.569s
# INFO:tensorflow:{'Loss/classification_loss': 0.30935237,
#  'Loss/localization_loss': 0.17767693,
#  'Loss/regularization_loss': 4.0145297,
#  'Loss/total_loss': 4.5015593,
#  'learning_rate': 0.037757702}
# I1015 05:28:55.996117 140438086686592 model_lib_v2.py:708] {'Loss/classification_loss': 0.30935237,
#  'Loss/localization_loss': 0.17767693,
#  'Loss/regularization_loss': 4.0145297,
#  'Loss/total_loss': 4.5015593,
#  'learning_rate': 0.037757702}
# INFO:tensorflow:Step 5600 per-step time 0.570s
# I1015 05:29:52.954714 140438086686592 model_lib_v2.py:707] Step 5600 per-step time 0.570s
# INFO:tensorflow:{'Loss/classification_loss': 0.29031065,
#  'Loss/localization_loss': 0.17995086,
#  'Loss/regularization_loss': 3.8984182,
#  'Loss/total_loss': 4.3686795,
#  'learning_rate': 0.03763037}
# I1015 05:29:52.955019 140438086686592 model_lib_v2.py:708] {'Loss/classification_loss': 0.29031065,
#  'Loss/localization_loss': 0.17995086,
#  'Loss/regularization_loss': 3.8984182,
#  'Loss/total_loss': 4.3686795,
#  'learning_rate': 0.03763037}
# INFO:tensorflow:Step 5700 per-step time 0.570s
# I1015 05:30:49.967200 140438086686592 model_lib_v2.py:707] Step 5700 per-step time 0.570s
# INFO:tensorflow:{'Loss/classification_loss': 0.3024446,
#  'Loss/localization_loss': 0.18259613,
#  'Loss/regularization_loss': 3.7857566,
#  'Loss/total_loss': 4.2707973,
#  'learning_rate': 0.03749975}
# I1015 05:30:49.967599 140438086686592 model_lib_v2.py:708] {'Loss/classification_loss': 0.3024446,
#  'Loss/localization_loss': 0.18259613,
#  'Loss/regularization_loss': 3.7857566,
#  'Loss/total_loss': 4.2707973,
#  'learning_rate': 0.03749975}
# INFO:tensorflow:Step 5800 per-step time 0.569s
# I1015 05:31:46.885836 140438086686592 model_lib_v2.py:707] Step 5800 per-step time 0.569s
# INFO:tensorflow:{'Loss/classification_loss': 0.41552693,
#  'Loss/localization_loss': 0.29019776,
#  'Loss/regularization_loss': 3.677026,
#  'Loss/total_loss': 4.3827505,
#  'learning_rate': 0.037365858}
# I1015 05:31:46.886152 140438086686592 model_lib_v2.py:708] {'Loss/classification_loss': 0.41552693,
#  'Loss/localization_loss': 0.29019776,
#  'Loss/regularization_loss': 3.677026,
#  'Loss/total_loss': 4.3827505,
#  'learning_rate': 0.037365858}
# INFO:tensorflow:Step 5900 per-step time 0.569s
# I1015 05:32:43.825297 140438086686592 model_lib_v2.py:707] Step 5900 per-step time 0.569s
# INFO:tensorflow:{'Loss/classification_loss': 0.34367368,
#  'Loss/localization_loss': 0.186699,
#  'Loss/regularization_loss': 3.5719028,
#  'Loss/total_loss': 4.1022754,
#  'learning_rate': 0.03722873}
# I1015 05:32:43.825620 140438086686592 model_lib_v2.py:708] {'Loss/classification_loss': 0.34367368,
#  'Loss/localization_loss': 0.186699,
#  'Loss/regularization_loss': 3.5719028,
#  'Loss/total_loss': 4.1022754,
#  'learning_rate': 0.03722873}
# INFO:tensorflow:Step 6000 per-step time 0.569s
# I1015 05:33:40.717921 140438086686592 model_lib_v2.py:707] Step 6000 per-step time 0.569s
# INFO:tensorflow:{'Loss/classification_loss': 0.33191442,
#  'Loss/localization_loss': 0.21920583,
#  'Loss/regularization_loss': 3.470171,
#  'Loss/total_loss': 4.0212913,
#  'learning_rate': 0.037088387}
# I1015 05:33:40.718228 140438086686592 model_lib_v2.py:708] {'Loss/classification_loss': 0.33191442,
#  'Loss/localization_loss': 0.21920583,
#  'Loss/regularization_loss': 3.470171,
#  'Loss/total_loss': 4.0212913,
#  'learning_rate': 0.037088387}
# INFO:tensorflow:Step 6100 per-step time 0.592s
# I1015 05:34:39.951388 140438086686592 model_lib_v2.py:707] Step 6100 per-step time 0.592s
# INFO:tensorflow:{'Loss/classification_loss': 0.2999076,
#  'Loss/localization_loss': 0.15356003,
#  'Loss/regularization_loss': 3.3718174,
#  'Loss/total_loss': 3.825285,
#  'learning_rate': 0.036944855}
# I1015 05:34:39.951706 140438086686592 model_lib_v2.py:708] {'Loss/classification_loss': 0.2999076,
#  'Loss/localization_loss': 0.15356003,
#  'Loss/regularization_loss': 3.3718174,
#  'Loss/total_loss': 3.825285,
#  'learning_rate': 0.036944855}
# INFO:tensorflow:Step 6200 per-step time 0.569s
# I1015 05:35:36.872855 140438086686592 model_lib_v2.py:707] Step 6200 per-step time 0.569s
# INFO:tensorflow:{'Loss/classification_loss': 0.32411957,
#  'Loss/localization_loss': 0.18617804,
#  'Loss/regularization_loss': 3.2776,
#  'Loss/total_loss': 3.7878976,
#  'learning_rate': 0.036798168}
# I1015 05:35:36.873163 140438086686592 model_lib_v2.py:708] {'Loss/classification_loss': 0.32411957,
#  'Loss/localization_loss': 0.18617804,
#  'Loss/regularization_loss': 3.2776,
#  'Loss/total_loss': 3.7878976,
#  'learning_rate': 0.036798168}
# INFO:tensorflow:Step 6300 per-step time 0.570s
# I1015 05:36:33.839237 140438086686592 model_lib_v2.py:707] Step 6300 per-step time 0.570s
# INFO:tensorflow:{'Loss/classification_loss': 0.26085806,
#  'Loss/localization_loss': 0.138562,
#  'Loss/regularization_loss': 3.1858678,
#  'Loss/total_loss': 3.5852878,
#  'learning_rate': 0.03664834}
# I1015 05:36:33.839560 140438086686592 model_lib_v2.py:708] {'Loss/classification_loss': 0.26085806,
#  'Loss/localization_loss': 0.138562,
#  'Loss/regularization_loss': 3.1858678,
#  'Loss/total_loss': 3.5852878,
#  'learning_rate': 0.03664834}
# INFO:tensorflow:Step 6400 per-step time 0.568s
# I1015 05:37:30.658693 140438086686592 model_lib_v2.py:707] Step 6400 per-step time 0.568s
# INFO:tensorflow:{'Loss/classification_loss': 0.2793868,
# ...
#  'learning_rate': 0.012536017}
# I1015 07:11:57.019561 140438086686592 model_lib_v2.py:708] {'Loss/classification_loss': 0.13321228,
#  'Loss/localization_loss': 0.051729657,
#  'Loss/regularization_loss': 0.50659955,
#  'Loss/total_loss': 0.6915415,
#  'learning_rate': 0.012536017}
# INFO:tensorflow:Step 16400 per-step time 0.570s
# I1015 07:12:54.036048 140438086686592 model_lib_v2.py:707] Step 16400 per-step time 0.570s
# INFO:tensorflow:{'Loss/classification_loss': 0.19285299,
#  'Loss/localization_loss': 0.09797775,
#  'Loss/regularization_loss': 0.5023065,
#  'Loss/total_loss': 0.79313725,
#  'learning_rate': 0.01228328}
# I1015 07:12:54.036357 140438086686592 model_lib_v2.py:708] {'Loss/classification_loss': 0.19285299,
#  'Loss/localization_loss': 0.09797775,
#  'Loss/regularization_loss': 0.5023065,
#  'Loss/total_loss': 0.79313725,
#  'learning_rate': 0.01228328}
# INFO:tensorflow:Step 16500 per-step time 0.571s
# I1015 07:13:51.171560 140438086686592 model_lib_v2.py:707] Step 16500 per-step time 0.571s
# INFO:tensorflow:{'Loss/classification_loss': 0.09134201,
#  'Loss/localization_loss': 0.035735168,
#  'Loss/regularization_loss': 0.49807188,
#  'Loss/total_loss': 0.6251491,
#  'learning_rate': 0.012031979}
# I1015 07:13:51.171849 140438086686592 model_lib_v2.py:708] {'Loss/classification_loss': 0.09134201,
#  'Loss/localization_loss': 0.035735168,
#  'Loss/regularization_loss': 0.49807188,
#  'Loss/total_loss': 0.6251491,
#  'learning_rate': 0.012031979}
# INFO:tensorflow:Step 16600 per-step time 0.570s
# I1015 07:14:48.141749 140438086686592 model_lib_v2.py:707] Step 16600 per-step time 0.570s
# INFO:tensorflow:{'Loss/classification_loss': 0.10931371,
#  'Loss/localization_loss': 0.031071944,
#  'Loss/regularization_loss': 0.4939077,
#  'Loss/total_loss': 0.6342933,
#  'learning_rate': 0.011782162}
# I1015 07:14:48.142116 140438086686592 model_lib_v2.py:708] {'Loss/classification_loss': 0.10931371,
#  'Loss/localization_loss': 0.031071944,
#  'Loss/regularization_loss': 0.4939077,
#  'Loss/total_loss': 0.6342933,
#  'learning_rate': 0.011782162}
# INFO:tensorflow:Step 16700 per-step time 0.571s
# I1015 07:15:45.273596 140438086686592 model_lib_v2.py:707] Step 16700 per-step time 0.571s
# INFO:tensorflow:{'Loss/classification_loss': 0.11718451,
#  'Loss/localization_loss': 0.05307395,
#  'Loss/regularization_loss': 0.48979643,
#  'Loss/total_loss': 0.6600549,
#  'learning_rate': 0.01153388}
# I1015 07:15:45.273881 140438086686592 model_lib_v2.py:708] {'Loss/classification_loss': 0.11718451,
#  'Loss/localization_loss': 0.05307395,
#  'Loss/regularization_loss': 0.48979643,
#  'Loss/total_loss': 0.6600549,
#  'learning_rate': 0.01153388}
# INFO:tensorflow:Step 16800 per-step time 0.572s
# I1015 07:16:42.424560 140438086686592 model_lib_v2.py:707] Step 16800 per-step time 0.572s
# INFO:tensorflow:{'Loss/classification_loss': 0.11535539,
#  'Loss/localization_loss': 0.04246041,
#  'Loss/regularization_loss': 0.48580033,
#  'Loss/total_loss': 0.64361614,
#  'learning_rate': 0.01128718}
# I1015 07:16:42.424882 140438086686592 model_lib_v2.py:708] {'Loss/classification_loss': 0.11535539,
#  'Loss/localization_loss': 0.04246041,
#  'Loss/regularization_loss': 0.48580033,
#  'Loss/total_loss': 0.64361614,
#  'learning_rate': 0.01128718}
# INFO:tensorflow:Step 16900 per-step time 0.570s
# I1015 07:17:39.429901 140438086686592 model_lib_v2.py:707] Step 16900 per-step time 0.570s
# INFO:tensorflow:{'Loss/classification_loss': 0.092247754,
#  'Loss/localization_loss': 0.033239495,
#  'Loss/regularization_loss': 0.48191032,
#  'Loss/total_loss': 0.60739756,
#  'learning_rate': 0.011042106}
# I1015 07:17:39.430239 140438086686592 model_lib_v2.py:708] {'Loss/classification_loss': 0.092247754,
#  'Loss/localization_loss': 0.033239495,
#  'Loss/regularization_loss': 0.48191032,
#  'Loss/total_loss': 0.60739756,
#  'learning_rate': 0.011042106}
# INFO:tensorflow:Step 17000 per-step time 0.572s
# I1015 07:18:36.600843 140438086686592 model_lib_v2.py:707] Step 17000 per-step time 0.572s
# INFO:tensorflow:{'Loss/classification_loss': 0.19842519,
#  'Loss/localization_loss': 0.11576744,
#  'Loss/regularization_loss': 0.47813395,
#  'Loss/total_loss': 0.79232657,
#  'learning_rate': 0.010798697}
# I1015 07:18:36.601179 140438086686592 model_lib_v2.py:708] {'Loss/classification_loss': 0.19842519,
#  'Loss/localization_loss': 0.11576744,
#  'Loss/regularization_loss': 0.47813395,
#  'Loss/total_loss': 0.79232657,
#  'learning_rate': 0.010798697}
# INFO:tensorflow:Step 17100 per-step time 0.593s
# I1015 07:19:35.862080 140438086686592 model_lib_v2.py:707] Step 17100 per-step time 0.593s
# INFO:tensorflow:{'Loss/classification_loss': 0.11932512,
#  'Loss/localization_loss': 0.0501443,
#  'Loss/regularization_loss': 0.47455364,
#  'Loss/total_loss': 0.64402306,
#  'learning_rate': 0.010557013}
# I1015 07:19:35.862385 140438086686592 model_lib_v2.py:708] {'Loss/classification_loss': 0.11932512,
#  'Loss/localization_loss': 0.0501443,
#  'Loss/regularization_loss': 0.47455364,
#  'Loss/total_loss': 0.64402306,
#  'learning_rate': 0.010557013}
# INFO:tensorflow:Step 17200 per-step time 0.571s
# I1015 07:20:32.959559 140438086686592 model_lib_v2.py:707] Step 17200 per-step time 0.571s
# INFO:tensorflow:{'Loss/classification_loss': 0.120114625,
#  'Loss/localization_loss': 0.055489447,
#  'Loss/regularization_loss': 0.471021,
#  'Loss/total_loss': 0.64662504,
#  'learning_rate': 0.0103170825}
# I1015 07:20:32.959870 140438086686592 model_lib_v2.py:708] {'Loss/classification_loss': 0.120114625,
#  'Loss/localization_loss': 0.055489447,
#  'Loss/regularization_loss': 0.471021,
#  'Loss/total_loss': 0.64662504,
#  'learning_rate': 0.0103170825}
# INFO:tensorflow:Step 17300 per-step time 0.571s
# I1015 07:21:30.034476 140438086686592 model_lib_v2.py:707] Step 17300 per-step time 0.571s
# INFO:tensorflow:{'Loss/classification_loss': 0.08242907,
#  'Loss/localization_loss': 0.05043908,
#  'Loss/regularization_loss': 0.4675675,
#  'Loss/total_loss': 0.6004356,
#  'learning_rate': 0.010078964}
# I1015 07:21:30.034770 140438086686592 model_lib_v2.py:708] {'Loss/classification_loss': 0.08242907,
#  'Loss/localization_loss': 0.05043908,
#  'Loss/regularization_loss': 0.4675675,
#  'Loss/total_loss': 0.6004356,
#  'learning_rate': 0.010078964}
# INFO:tensorflow:Step 17400 per-step time 0.570s
# I1015 07:22:27.022139 140438086686592 model_lib_v2.py:707] Step 17400 per-step time 0.570s
# INFO:tensorflow:{'Loss/classification_loss': 0.12594453,
#  'Loss/localization_loss': 0.047535107,
#  'Loss/regularization_loss': 0.46420524,
#  'Loss/total_loss': 0.6376849,
#  'learning_rate': 0.009842696}
# I1015 07:22:27.022449 140438086686592 model_lib_v2.py:708] {'Loss/classification_loss': 0.12594453,
#  'Loss/localization_loss': 0.047535107,
#  'Loss/regularization_loss': 0.46420524,
#  'Loss/total_loss': 0.6376849,
#  'learning_rate': 0.009842696}
# INFO:tensorflow:Step 17500 per-step time 0.571s
# I1015 07:23:24.117939 140438086686592 model_lib_v2.py:707] Step 17500 per-step time 0.571s
# INFO:tensorflow:{'Loss/classification_loss': 0.11886095,
#  'Loss/localization_loss': 0.040868066,
#  'Loss/regularization_loss': 0.46095154,
#  'Loss/total_loss': 0.6206806,
#  'learning_rate': 0.00960832}
# I1015 07:23:24.118228 140438086686592 model_lib_v2.py:708] {'Loss/classification_loss': 0.11886095,
#  'Loss/localization_loss': 0.040868066,
#  'Loss/regularization_loss': 0.46095154,
#  'Loss/total_loss': 0.6206806,
#  'learning_rate': 0.00960832}
# INFO:tensorflow:Step 17600 per-step time 0.571s
# I1015 07:24:21.212185 140438086686592 model_lib_v2.py:707] Step 17600 per-step time 0.571s
# INFO:tensorflow:{'Loss/classification_loss': 0.09744893,
#  'Loss/localization_loss': 0.036639635,
#  'Loss/regularization_loss': 0.45782512,
#  'Loss/total_loss': 0.5919137,
#  'learning_rate': 0.009375882}
# I1015 07:24:21.212492 140438086686592 model_lib_v2.py:708] {'Loss/classification_loss': 0.09744893,
#  'Loss/localization_loss': 0.036639635,
#  'Loss/regularization_loss': 0.45782512,
#  'Loss/total_loss': 0.5919137,
#  'learning_rate': 0.009375882}
# INFO:tensorflow:Step 17700 per-step time 0.571s
# I1015 07:25:18.358395 140438086686592 model_lib_v2.py:707] Step 17700 per-step time 0.571s
# INFO:tensorflow:{'Loss/classification_loss': 0.14070411,
#  'Loss/localization_loss': 0.057535276,
#  'Loss/regularization_loss': 0.4547643,
#  'Loss/total_loss': 0.6530037,
#  'learning_rate': 0.00914543}
# I1015 07:25:18.358697 140438086686592 model_lib_v2.py:708] {'Loss/classification_loss': 0.14070411,
#  'Loss/localization_loss': 0.057535276,
#  'Loss/regularization_loss': 0.4547643,
#  'Loss/total_loss': 0.6530037,
#  'learning_rate': 0.00914543}
# INFO:tensorflow:Step 17800 per-step time 0.571s
# I1015 07:26:15.483595 140438086686592 model_lib_v2.py:707] Step 17800 per-step time 0.571s
# INFO:tensorflow:{'Loss/classification_loss': 0.11146315,
#  'Loss/localization_loss': 0.042215016,
#  'Loss/regularization_loss': 0.45181936,
#  'Loss/total_loss': 0.60549754,
#  'learning_rate': 0.008917004}
# I1015 07:26:15.483961 140438086686592 model_lib_v2.py:708] {'Loss/classification_loss': 0.11146315,
#  'Loss/localization_loss': 0.042215016,
#  'Loss/regularization_loss': 0.45181936,
#  'Loss/total_loss': 0.60549754,
#  'learning_rate': 0.008917004}
# INFO:tensorflow:Step 17900 per-step time 0.572s
# I1015 07:27:12.638424 140438086686592 model_lib_v2.py:707] Step 17900 per-step time 0.572s
# INFO:tensorflow:{'Loss/classification_loss': 0.09083571,
#  'Loss/localization_loss': 0.03623753,
#  'Loss/regularization_loss': 0.44892544,
#  'Loss/total_loss': 0.57599866,
#  'learning_rate': 0.00869064}
# I1015 07:27:12.638728 140438086686592 model_lib_v2.py:708] {'Loss/classification_loss': 0.09083571,
#  'Loss/localization_loss': 0.03623753,
#  'Loss/regularization_loss': 0.44892544,
#  'Loss/total_loss': 0.57599866,
#  'learning_rate': 0.00869064}
# INFO:tensorflow:Step 18000 per-step time 0.572s
# I1015 07:28:09.852248 140438086686592 model_lib_v2.py:707] Step 18000 per-step time 0.572s
# INFO:tensorflow:{'Loss/classification_loss': 0.06752654,
#  'Loss/localization_loss': 0.023455033,
#  'Loss/regularization_loss': 0.44612417,
#  'Loss/total_loss': 0.53710574,
#  'learning_rate': 0.008466393}
# I1015 07:28:09.852560 140438086686592 model_lib_v2.py:708] {'Loss/classification_loss': 0.06752654,
#  'Loss/localization_loss': 0.023455033,
#  'Loss/regularization_loss': 0.44612417,
#  'Loss/total_loss': 0.53710574,
#  'learning_rate': 0.008466393}
# INFO:tensorflow:Step 18100 per-step time 0.590s
# I1015 07:29:08.875067 140438086686592 model_lib_v2.py:707] Step 18100 per-step time 0.590s
# INFO:tensorflow:{'Loss/classification_loss': 0.12561393,
#  'Loss/localization_loss': 0.08253242,
#  'Loss/regularization_loss': 0.44342953,
#  'Loss/total_loss': 0.65157586,
#  'learning_rate': 0.008244291}
# I1015 07:29:08.875433 140438086686592 model_lib_v2.py:708] {'Loss/classification_loss': 0.12561393,
#  'Loss/localization_loss': 0.08253242,
#  'Loss/regularization_loss': 0.44342953,
#  'Loss/total_loss': 0.65157586,
#  'learning_rate': 0.008244291}
# INFO:tensorflow:Step 18200 per-step time 0.572s
# I1015 07:30:06.067802 140438086686592 model_lib_v2.py:707] Step 18200 per-step time 0.572s
# INFO:tensorflow:{'Loss/classification_loss': 0.072211176,
#  'Loss/localization_loss': 0.039781187,
#  'Loss/regularization_loss': 0.44081554,
#  'Loss/total_loss': 0.5528079,
#  'learning_rate': 0.008024387}
# I1015 07:30:06.068118 140438086686592 model_lib_v2.py:708] {'Loss/classification_loss': 0.072211176,
#  'Loss/localization_loss': 0.039781187,
#  'Loss/regularization_loss': 0.44081554,
#  'Loss/total_loss': 0.5528079,
#  'learning_rate': 0.008024387}
# INFO:tensorflow:Step 18300 per-step time 0.572s
# I1015 07:31:03.224387 140438086686592 model_lib_v2.py:707] Step 18300 per-step time 0.572s
# INFO:tensorflow:{'Loss/classification_loss': 0.1298551,
#  'Loss/localization_loss': 0.02390258,
#  'Loss/regularization_loss': 0.43826905,
#  'Loss/total_loss': 0.5920267,
#  'learning_rate': 0.0078067183}
# I1015 07:31:03.224765 140438086686592 model_lib_v2.py:708] {'Loss/classification_loss': 0.1298551,
#  'Loss/localization_loss': 0.02390258,
#  'Loss/regularization_loss': 0.43826905,
#  'Loss/total_loss': 0.5920267,
#  'learning_rate': 0.0078067183}
# INFO:tensorflow:Step 18400 per-step time 0.572s
# I1015 07:32:00.400083 140438086686592 model_lib_v2.py:707] Step 18400 per-step time 0.572s
# INFO:tensorflow:{'Loss/classification_loss': 0.09911246,
#  'Loss/localization_loss': 0.022205088,
#  'Loss/regularization_loss': 0.43579936,
#  'Loss/total_loss': 0.5571169,
#  'learning_rate': 0.00759132}
# I1015 07:32:00.400397 140438086686592 model_lib_v2.py:708] {'Loss/classification_loss': 0.09911246,
#  'Loss/localization_loss': 0.022205088,
#  'Loss/regularization_loss': 0.43579936,
#  'Loss/total_loss': 0.5571169,
#  'learning_rate': 0.00759132}
# INFO:tensorflow:Step 18500 per-step time 0.572s
# I1015 07:32:57.580152 140438086686592 model_lib_v2.py:707] Step 18500 per-step time 0.572s
# INFO:tensorflow:{'Loss/classification_loss': 0.08654329,
#  'Loss/localization_loss': 0.036723148,
#  'Loss/regularization_loss': 0.43341404,
#  'Loss/total_loss': 0.5566805,
#  'learning_rate': 0.0073782397}
# I1015 07:32:57.580467 140438086686592 model_lib_v2.py:708] {'Loss/classification_loss': 0.08654329,
#  'Loss/localization_loss': 0.036723148,
#  'Loss/regularization_loss': 0.43341404,
#  'Loss/total_loss': 0.5566805,
#  'learning_rate': 0.0073782397}
# INFO:tensorflow:Step 18600 per-step time 0.572s
# I1015 07:33:54.756220 140438086686592 model_lib_v2.py:707] Step 18600 per-step time 0.572s
# INFO:tensorflow:{'Loss/classification_loss': 0.10773033,
#  'Loss/localization_loss': 0.041512776,
#  'Loss/regularization_loss': 0.4310852,
#  'Loss/total_loss': 0.5803283,
#  'learning_rate': 0.007167512}
# I1015 07:33:54.756526 140438086686592 model_lib_v2.py:708] {'Loss/classification_loss': 0.10773033,
#  'Loss/localization_loss': 0.041512776,
#  'Loss/regularization_loss': 0.4310852,
#  'Loss/total_loss': 0.5803283,
#  'learning_rate': 0.007167512}
# INFO:tensorflow:Step 18700 per-step time 0.572s
# I1015 07:34:51.905250 140438086686592 model_lib_v2.py:707] Step 18700 per-step time 0.572s
# INFO:tensorflow:{'Loss/classification_loss': 0.11457138,
#  'Loss/localization_loss': 0.027329119,
#  'Loss/regularization_loss': 0.42884994,
#  'Loss/total_loss': 0.5707504,
#  'learning_rate': 0.006959181}
# I1015 07:34:51.905565 140438086686592 model_lib_v2.py:708] {'Loss/classification_loss': 0.11457138,
#  'Loss/localization_loss': 0.027329119,
#  'Loss/regularization_loss': 0.42884994,
#  'Loss/total_loss': 0.5707504,
#  'learning_rate': 0.006959181}
# INFO:tensorflow:Step 18800 per-step time 0.572s
# I1015 07:35:49.073111 140438086686592 model_lib_v2.py:707] Step 18800 per-step time 0.572s
# INFO:tensorflow:{'Loss/classification_loss': 0.09228502,
#  'Loss/localization_loss': 0.021059671,
#  'Loss/regularization_loss': 0.4266917,
#  'Loss/total_loss': 0.5400364,
#  'learning_rate': 0.0067532836}
# I1015 07:35:49.073406 140438086686592 model_lib_v2.py:708] {'Loss/classification_loss': 0.09228502,
#  'Loss/localization_loss': 0.021059671,
#  'Loss/regularization_loss': 0.4266917,
#  'Loss/total_loss': 0.5400364,
#  'learning_rate': 0.0067532836}
# INFO:tensorflow:Step 18900 per-step time 0.572s
# I1015 07:36:46.243167 140438086686592 model_lib_v2.py:707] Step 18900 per-step time 0.572s
# INFO:tensorflow:{'Loss/classification_loss': 0.09129239,
#  'Loss/localization_loss': 0.04044203,
#  'Loss/regularization_loss': 0.42459416,
#  'Loss/total_loss': 0.5563286,
#  'learning_rate': 0.006549853}
# I1015 07:36:46.243546 140438086686592 model_lib_v2.py:708] {'Loss/classification_loss': 0.09129239,
#  'Loss/localization_loss': 0.04044203,
#  'Loss/regularization_loss': 0.42459416,
#  'Loss/total_loss': 0.5563286,
#  'learning_rate': 0.006549853}
# INFO:tensorflow:Step 19000 per-step time 0.571s
# I1015 07:37:43.336879 140438086686592 model_lib_v2.py:707] Step 19000 per-step time 0.571s
# INFO:tensorflow:{'Loss/classification_loss': 0.1246851,
#  'Loss/localization_loss': 0.060395226,
#  'Loss/regularization_loss': 0.42257547,
#  'Loss/total_loss': 0.60765576,
#  'learning_rate': 0.0063489364}
# I1015 07:37:43.337216 140438086686592 model_lib_v2.py:708] {'Loss/classification_loss': 0.1246851,
#  'Loss/localization_loss': 0.060395226,
#  'Loss/regularization_loss': 0.42257547,
#  'Loss/total_loss': 0.60765576,
#  'learning_rate': 0.0063489364}

# %% [markdown]
# # 7. Evaluate the Model

# %%
command = "python {} --model_dir={} --pipeline_config_path={} --checkpoint_dir={}".format(TRAINING_SCRIPT, paths['CHECKPOINT_PATH'],files['PIPELINE_CONFIG'], paths['CHECKPOINT_PATH'])

# %%
print(command)
# Out:
# python Tensorflow/models/research/object_detection/model_main_tf2.py --model_dir=Tensorflow/workspace/models/my_ssd_resnet50_v1_fpn_640x640 --pipeline_config_path=Tensorflow/workspace/models/my_ssd_resnet50_v1_fpn_640x640/pipeline.config --checkpoint_dir=Tensorflow/workspace/models/my_ssd_resnet50_v1_fpn_640x640

# %%
# !{command}
# Out:
# 2022-10-15 17:40:23.883256: E tensorflow/stream_executor/cuda/cuda_blas.cc:2981] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2022-10-15 17:40:24.650742: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer.so.7'; dlerror: libnvinfer.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/lib64-nvidia
# 2022-10-15 17:40:24.650857: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer_plugin.so.7'; dlerror: libnvinfer_plugin.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/lib64-nvidia
# 2022-10-15 17:40:24.650882: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Cannot dlopen some TensorRT libraries. If you would like to use Nvidia GPU with TensorRT, please make sure the missing libraries mentioned above are installed properly.
# WARNING:tensorflow:Forced number of epochs for all eval validations to be 1.
# W1015 17:40:27.402873 140583662671744 model_lib_v2.py:1090] Forced number of epochs for all eval validations to be 1.
# INFO:tensorflow:Maybe overwriting sample_1_of_n_eval_examples: None
# I1015 17:40:27.403112 140583662671744 config_util.py:552] Maybe overwriting sample_1_of_n_eval_examples: None
# INFO:tensorflow:Maybe overwriting use_bfloat16: False
# I1015 17:40:27.403201 140583662671744 config_util.py:552] Maybe overwriting use_bfloat16: False
# INFO:tensorflow:Maybe overwriting eval_num_epochs: 1
# I1015 17:40:27.403289 140583662671744 config_util.py:552] Maybe overwriting eval_num_epochs: 1
# WARNING:tensorflow:Expected number of evaluation epochs is 1, but instead encountered `eval_on_train_input_config.num_epochs` = 0. Overwriting `num_epochs` to 1.
# W1015 17:40:27.403404 140583662671744 model_lib_v2.py:1110] Expected number of evaluation epochs is 1, but instead encountered `eval_on_train_input_config.num_epochs` = 0. Overwriting `num_epochs` to 1.
# 2022-10-15 17:40:28.215280: W tensorflow/core/common_runtime/gpu/gpu_bfc_allocator.cc:42] Overriding orig_value setting because the TF_FORCE_GPU_ALLOW_GROWTH environment variable is set. Original config value was 0.
# INFO:tensorflow:Reading unweighted datasets: ['Tensorflow/workspace/annotations/test.record']
# I1015 17:40:28.710835 140583662671744 dataset_builder.py:162] Reading unweighted datasets: ['Tensorflow/workspace/annotations/test.record']
# INFO:tensorflow:Reading record datasets for input file: ['Tensorflow/workspace/annotations/test.record']
# I1015 17:40:28.711306 140583662671744 dataset_builder.py:79] Reading record datasets for input file: ['Tensorflow/workspace/annotations/test.record']
# INFO:tensorflow:Number of filenames to read: 1
# I1015 17:40:28.711456 140583662671744 dataset_builder.py:80] Number of filenames to read: 1
# WARNING:tensorflow:num_readers has been reduced to 1 to match input file shards.
# W1015 17:40:28.711527 140583662671744 dataset_builder.py:87] num_readers has been reduced to 1 to match input file shards.
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/object_detection/builders/dataset_builder.py:104: parallel_interleave (from tensorflow.python.data.experimental.ops.interleave_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.data.Dataset.interleave(map_func, cycle_length, block_length, num_parallel_calls=tf.data.AUTOTUNE)` instead. If sloppy execution is desired, use `tf.data.Options.deterministic`.
# W1015 17:40:28.715203 140583662671744 deprecation.py:356] From /usr/local/lib/python3.7/dist-packages/object_detection/builders/dataset_builder.py:104: parallel_interleave (from tensorflow.python.data.experimental.ops.interleave_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.data.Dataset.interleave(map_func, cycle_length, block_length, num_parallel_calls=tf.data.AUTOTUNE)` instead. If sloppy execution is desired, use `tf.data.Options.deterministic`.
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/object_detection/builders/dataset_builder.py:236: DatasetV1.map_with_legacy_function (from tensorflow.python.data.ops.dataset_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.data.Dataset.map()
# W1015 17:40:28.731678 140583662671744 deprecation.py:356] From /usr/local/lib/python3.7/dist-packages/object_detection/builders/dataset_builder.py:236: DatasetV1.map_with_legacy_function (from tensorflow.python.data.ops.dataset_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.data.Dataset.map()
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/tensorflow/python/util/dispatch.py:1176: sparse_to_dense (from tensorflow.python.ops.sparse_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Create a `tf.sparse.SparseTensor` and use `tf.sparse.to_dense` instead.
# W1015 17:40:32.476858 140583662671744 deprecation.py:356] From /usr/local/lib/python3.7/dist-packages/tensorflow/python/util/dispatch.py:1176: sparse_to_dense (from tensorflow.python.ops.sparse_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Create a `tf.sparse.SparseTensor` and use `tf.sparse.to_dense` instead.
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/tensorflow/python/util/dispatch.py:1176: to_float (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.cast` instead.
# W1015 17:40:33.559520 140583662671744 deprecation.py:356] From /usr/local/lib/python3.7/dist-packages/tensorflow/python/util/dispatch.py:1176: to_float (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.cast` instead.
# INFO:tensorflow:Waiting for new checkpoint at Tensorflow/workspace/models/my_ssd_resnet50_v1_fpn_640x640
# I1015 17:40:35.980056 140583662671744 checkpoint_utils.py:142] Waiting for new checkpoint at Tensorflow/workspace/models/my_ssd_resnet50_v1_fpn_640x640
# INFO:tensorflow:Found new checkpoint at Tensorflow/workspace/models/my_ssd_resnet50_v1_fpn_640x640/ckpt-20
# I1015 17:40:36.442079 140583662671744 checkpoint_utils.py:151] Found new checkpoint at Tensorflow/workspace/models/my_ssd_resnet50_v1_fpn_640x640/ckpt-20
# /usr/local/lib/python3.7/dist-packages/keras/backend.py:452: UserWarning: `tf.keras.backend.set_learning_phase` is deprecated and will be removed after 2020-10-11. To update it, simply pass a True/False value to the `training` argument of the `__call__` method of your layer or model.
#   "`tf.keras.backend.set_learning_phase` is deprecated and "
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/tensorflow/python/util/dispatch.py:1176: to_int64 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.cast` instead.
# W1015 17:41:12.395970 140583662671744 deprecation.py:356] From /usr/local/lib/python3.7/dist-packages/tensorflow/python/util/dispatch.py:1176: to_int64 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.cast` instead.
# INFO:tensorflow:Finished eval step 0
# I1015 17:41:12.421249 140583662671744 model_lib_v2.py:966] Finished eval step 0
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/tensorflow/python/autograph/impl/api.py:459: py_func (from tensorflow.python.ops.script_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# tf.py_func is deprecated in TF V2. Instead, there are two
#     options available in V2.
#     - tf.py_function takes a python function which manipulates tf eager
#     tensors instead of numpy arrays. It's easy to convert a tf eager tensor to
#     an ndarray (just call tensor.numpy()) but having access to eager tensors
#     means `tf.py_function`s can use accelerators such as GPUs as well as
#     being differentiable using a gradient tape.
#     - tf.numpy_function maintains the semantics of the deprecated tf.py_func
#     (it is not differentiable, and manipulates numpy arrays). It drops the
#     stateful argument making all functions stateful.
#
# W1015 17:41:12.568066 140583662671744 deprecation.py:356] From /usr/local/lib/python3.7/dist-packages/tensorflow/python/autograph/impl/api.py:459: py_func (from tensorflow.python.ops.script_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# tf.py_func is deprecated in TF V2. Instead, there are two
#     options available in V2.
#     - tf.py_function takes a python function which manipulates tf eager
#     tensors instead of numpy arrays. It's easy to convert a tf eager tensor to
#     an ndarray (just call tensor.numpy()) but having access to eager tensors
#     means `tf.py_function`s can use accelerators such as GPUs as well as
#     being differentiable using a gradient tape.
#     - tf.numpy_function maintains the semantics of the deprecated tf.py_func
#     (it is not differentiable, and manipulates numpy arrays). It drops the
#     stateful argument making all functions stateful.
#
# INFO:tensorflow:Performing evaluation on 29 images.
# I1015 17:41:21.219247 140583662671744 coco_evaluation.py:293] Performing evaluation on 29 images.
# creating index...
# index created!
# INFO:tensorflow:Loading and preparing annotation results...
# I1015 17:41:21.219681 140583662671744 coco_tools.py:116] Loading and preparing annotation results...
# INFO:tensorflow:DONE (t=0.00s)
# I1015 17:41:21.221351 140583662671744 coco_tools.py:138] DONE (t=0.00s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *bbox*
# DONE (t=0.25s).
# Accumulating evaluation results...
# DONE (t=0.04s).
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.238
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.523
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.191
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.030
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.271
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.405
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.147
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.374
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.412
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.154
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.432
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.594
# INFO:tensorflow:Eval metrics at step 19000
# I1015 17:41:21.515923 140583662671744 model_lib_v2.py:1015] Eval metrics at step 19000
# INFO:tensorflow:	+ DetectionBoxes_Precision/mAP: 0.238423
# I1015 17:41:21.532407 140583662671744 model_lib_v2.py:1018] 	+ DetectionBoxes_Precision/mAP: 0.238423
# INFO:tensorflow:	+ DetectionBoxes_Precision/mAP@.50IOU: 0.523169
# I1015 17:41:21.534104 140583662671744 model_lib_v2.py:1018] 	+ DetectionBoxes_Precision/mAP@.50IOU: 0.523169
# INFO:tensorflow:	+ DetectionBoxes_Precision/mAP@.75IOU: 0.191364
# I1015 17:41:21.535853 140583662671744 model_lib_v2.py:1018] 	+ DetectionBoxes_Precision/mAP@.75IOU: 0.191364
# INFO:tensorflow:	+ DetectionBoxes_Precision/mAP (small): 0.030194
# I1015 17:41:21.537413 140583662671744 model_lib_v2.py:1018] 	+ DetectionBoxes_Precision/mAP (small): 0.030194
# INFO:tensorflow:	+ DetectionBoxes_Precision/mAP (medium): 0.270802
# I1015 17:41:21.538877 140583662671744 model_lib_v2.py:1018] 	+ DetectionBoxes_Precision/mAP (medium): 0.270802
# INFO:tensorflow:	+ DetectionBoxes_Precision/mAP (large): 0.404646
# I1015 17:41:21.540318 140583662671744 model_lib_v2.py:1018] 	+ DetectionBoxes_Precision/mAP (large): 0.404646
# INFO:tensorflow:	+ DetectionBoxes_Recall/AR@1: 0.146937
# I1015 17:41:21.541752 140583662671744 model_lib_v2.py:1018] 	+ DetectionBoxes_Recall/AR@1: 0.146937
# INFO:tensorflow:	+ DetectionBoxes_Recall/AR@10: 0.374261
# I1015 17:41:21.543193 140583662671744 model_lib_v2.py:1018] 	+ DetectionBoxes_Recall/AR@10: 0.374261
# INFO:tensorflow:	+ DetectionBoxes_Recall/AR@100: 0.412324
# I1015 17:41:21.544600 140583662671744 model_lib_v2.py:1018] 	+ DetectionBoxes_Recall/AR@100: 0.412324
# INFO:tensorflow:	+ DetectionBoxes_Recall/AR@100 (small): 0.153571
# I1015 17:41:21.546048 140583662671744 model_lib_v2.py:1018] 	+ DetectionBoxes_Recall/AR@100 (small): 0.153571
# INFO:tensorflow:	+ DetectionBoxes_Recall/AR@100 (medium): 0.431944
# I1015 17:41:21.547410 140583662671744 model_lib_v2.py:1018] 	+ DetectionBoxes_Recall/AR@100 (medium): 0.431944
# INFO:tensorflow:	+ DetectionBoxes_Recall/AR@100 (large): 0.593571
# I1015 17:41:21.549129 140583662671744 model_lib_v2.py:1018] 	+ DetectionBoxes_Recall/AR@100 (large): 0.593571
# INFO:tensorflow:	+ Loss/localization_loss: 0.247800
# I1015 17:41:21.550225 140583662671744 model_lib_v2.py:1018] 	+ Loss/localization_loss: 0.247800
# INFO:tensorflow:	+ Loss/classification_loss: 0.427427
# I1015 17:41:21.551327 140583662671744 model_lib_v2.py:1018] 	+ Loss/classification_loss: 0.427427
# INFO:tensorflow:	+ Loss/regularization_loss: 0.422555
# I1015 17:41:21.553243 140583662671744 model_lib_v2.py:1018] 	+ Loss/regularization_loss: 0.422555
# INFO:tensorflow:	+ Loss/total_loss: 1.097782
# I1015 17:41:21.554572 140583662671744 model_lib_v2.py:1018] 	+ Loss/total_loss: 1.097782
# INFO:tensorflow:Waiting for new checkpoint at Tensorflow/workspace/models/my_ssd_resnet50_v1_fpn_640x640
# I1015 17:45:36.534537 140583662671744 checkpoint_utils.py:142] Waiting for new checkpoint at Tensorflow/workspace/models/my_ssd_resnet50_v1_fpn_640x640
# INFO:tensorflow:Timed-out waiting for a checkpoint.
# I1015 18:45:36.083332 140583662671744 checkpoint_utils.py:205] Timed-out waiting for a checkpoint.

# %%
#pwd

# %%
#cd '/content/drive/MyDrive/TFOD/Tensorflow/workspace/models/my_ssd_mobnet/train'

# %%
#pwd

# %%
#!tensorboard --logdir=.

# %%
#cd '/content/drive/MyDrive/TFOD'

# %% [markdown]
# # 8. Load Train Model From Checkpoint

# %%
import os
import tensorflow as tf
from object_detection.utils import label_map_util
from object_detection.utils import visualization_utils as viz_utils
from object_detection.builders import model_builder
from object_detection.utils import config_util

# %%
# Load pipeline config and build a detection model
configs = config_util.get_configs_from_pipeline_file(files['PIPELINE_CONFIG'])
detection_model = model_builder.build(model_config=configs['model'], is_training=False)

# Restore checkpoint
ckpt = tf.compat.v2.train.Checkpoint(model=detection_model)
ckpt.restore(os.path.join(paths['CHECKPOINT_PATH'], 'ckpt-20')).expect_partial()

@tf.function
def detect_fn(image):
    image, shapes = detection_model.preprocess(image)
    prediction_dict = detection_model.predict(image, shapes)
    detections = detection_model.postprocess(prediction_dict, shapes)
    return detections

# %% [markdown]
# # 9. Detect from an Image

# %%
# !pip install opencv-python
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: opencv-python in /usr/local/lib/python3.7/dist-packages (4.6.0.66)
# Requirement already satisfied: numpy>=1.14.5 in /usr/local/lib/python3.7/dist-packages (from opencv-python) (1.21.6)

# %%
import cv2 
import numpy as np
from matplotlib import pyplot as plt
# %matplotlib inline

# %%
category_index = label_map_util.create_category_index_from_labelmap(files['LABELMAP'])

# %%
testImagesPath = []
for root, dirs, files in os.walk(os.path.join(paths['IMAGE_PATH'], 'test')):
    for filename in files:
        if filename.find(".xml") == -1:
          testImagesPath.append(f"{root}/{filename}")

#testImagesPath

# %%
from pylab import rcParams

# %%
#8 random images to display at a time along with their true and random labels
rcParams['figure.figsize'] = 20, 10

num_row = 2
num_col = 4

imageId = np.random.randint(0, len(testImagesPath), num_row * num_col)

fig, axes = plt.subplots(num_row, num_col)

for i in range(0, num_row):
    for j in range(0, num_col):
        k = (i*num_col) + j

        img = cv2.imread(testImagesPath[imageId[k]])
        image_np = np.array(img)

        input_tensor = tf.convert_to_tensor(np.expand_dims(image_np, 0), dtype=tf.float32)
        detections = detect_fn(input_tensor)

        num_detections = int(detections.pop('num_detections'))
        detections = {key: value[0, :num_detections].numpy()
                    for key, value in detections.items()}
        detections['num_detections'] = num_detections

        # detection_classes should be ints.
        detections['detection_classes'] = detections['detection_classes'].astype(np.int64)

        label_id_offset = 1
        image_np_with_detections = image_np.copy()

        viz_utils.visualize_boxes_and_labels_on_image_array(
                  image_np_with_detections,
                  detections['detection_boxes'],
                  detections['detection_classes']+label_id_offset,
                  detections['detection_scores'],
                  category_index,
                  use_normalized_coordinates=True,
                  max_boxes_to_draw=5,
                  min_score_thresh=.8,
                  agnostic_mode=False)



        axes[i,j].imshow(cv2.cvtColor(image_np_with_detections, cv2.COLOR_BGR2RGB))
        # axes[i,j].set_title("True: " + str(sub_category.iloc[test['fine_labels'][imageId[k]]][0]).capitalize() 
        #                      + "\nPredicted: " + str(sub_category.iloc[prediction.iloc[imageId[k]]]).split()[2].capitalize(), 
        #                     fontsize=14)
        axes[i,j].axis('off')
        #fig.suptitle("Images with True and Predicted Labels", fontsize = 18) 

plt.show()

# %%
# for i in testImagesPath[:6]:
#   img = cv2.imread(i)
#   image_np = np.array(img)

#   input_tensor = tf.convert_to_tensor(np.expand_dims(image_np, 0), dtype=tf.float32)
#   detections = detect_fn(input_tensor)

#   num_detections = int(detections.pop('num_detections'))
#   detections = {key: value[0, :num_detections].numpy()
#               for key, value in detections.items()}
#   detections['num_detections'] = num_detections

#   # detection_classes should be ints.
#   detections['detection_classes'] = detections['detection_classes'].astype(np.int64)

#   label_id_offset = 1
#   image_np_with_detections = image_np.copy()

#   viz_utils.visualize_boxes_and_labels_on_image_array(
#             image_np_with_detections,
#             detections['detection_boxes'],
#             detections['detection_classes']+label_id_offset,
#             detections['detection_scores'],
#             category_index,
#             use_normalized_coordinates=True,
#             max_boxes_to_draw=5,
#             min_score_thresh=.8,
#             agnostic_mode=False)

#   plt.imshow(cv2.cvtColor(image_np_with_detections, cv2.COLOR_BGR2RGB))
#   plt.show()

# %%
#IMAGE_PATH = os.path.join(paths['IMAGE_PATH'], 'test', 'maksssksksss750.png')

# %%
# img = cv2.imread(IMAGE_PATH)
# image_np = np.array(img)

# input_tensor = tf.convert_to_tensor(np.expand_dims(image_np, 0), dtype=tf.float32)
# detections = detect_fn(input_tensor)

# num_detections = int(detections.pop('num_detections'))
# detections = {key: value[0, :num_detections].numpy()
#               for key, value in detections.items()}
# detections['num_detections'] = num_detections

# # detection_classes should be ints.
# detections['detection_classes'] = detections['detection_classes'].astype(np.int64)

# label_id_offset = 1
# image_np_with_detections = image_np.copy()

# viz_utils.visualize_boxes_and_labels_on_image_array(
#             image_np_with_detections,
#             detections['detection_boxes'],
#             detections['detection_classes']+label_id_offset,
#             detections['detection_scores'],
#             category_index,
#             use_normalized_coordinates=True,
#             max_boxes_to_draw=5,
#             min_score_thresh=.8,
#             agnostic_mode=False)

# plt.imshow(cv2.cvtColor(image_np_with_detections, cv2.COLOR_BGR2RGB))
# plt.show()

# %% [markdown]
# # 10. Real Time Detections from your Webcam

# %%
# !pip uninstall opencv-python-headless -y

# %%
cap = cv2.VideoCapture(0)
width = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
height = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))

while cap.isOpened(): 
    ret, frame = cap.read()
    image_np = np.array(frame)
    
    input_tensor = tf.convert_to_tensor(np.expand_dims(image_np, 0), dtype=tf.float32)
    detections = detect_fn(input_tensor)
    
    num_detections = int(detections.pop('num_detections'))
    detections = {key: value[0, :num_detections].numpy()
                  for key, value in detections.items()}
    detections['num_detections'] = num_detections

    # detection_classes should be ints.
    detections['detection_classes'] = detections['detection_classes'].astype(np.int64)

    label_id_offset = 1
    image_np_with_detections = image_np.copy()

    viz_utils.visualize_boxes_and_labels_on_image_array(
                image_np_with_detections,
                detections['detection_boxes'],
                detections['detection_classes']+label_id_offset,
                detections['detection_scores'],
                category_index,
                use_normalized_coordinates=True,
                max_boxes_to_draw=5,
                min_score_thresh=.8,
                agnostic_mode=False)

    cv2.imshow('object detection',  cv2.resize(image_np_with_detections, (800, 600)))
    
    if cv2.waitKey(10) & 0xFF == ord('q'):
        cap.release()
        cv2.destroyAllWindows()
        break

# %% [markdown]
# # 10. Freezing the Graph

# %%
FREEZE_SCRIPT = os.path.join(paths['APIMODEL_PATH'], 'research', 'object_detection', 'exporter_main_v2.py ')

# %%
command = "python {} --input_type=image_tensor --pipeline_config_path={} --trained_checkpoint_dir={} --output_directory={}".format(FREEZE_SCRIPT ,files['PIPELINE_CONFIG'], paths['CHECKPOINT_PATH'], paths['OUTPUT_PATH'])

# %%
print(command)
# Out:
# python Tensorflow\models\research\object_detection\exporter_main_v2.py  --input_type=image_tensor --pipeline_config_path=Tensorflow\workspace\models\my_ssd_mobnet\pipeline.config --trained_checkpoint_dir=Tensorflow\workspace\models\my_ssd_mobnet --output_directory=Tensorflow\workspace\models\my_ssd_mobnet\export

# %%
# !{command}
# Out:
# 2021-04-03 11:51:42.281339: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library cudart64_110.dll
# 2021-04-03 11:51:44.712115: I tensorflow/compiler/jit/xla_cpu_device.cc:41] Not creating XLA devices, tf_xla_enable_xla_devices not set
# 2021-04-03 11:51:44.712813: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library nvcuda.dll
# 2021-04-03 11:51:44.734951: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1720] Found device 0 with properties:
# pciBusID: 0000:2b:00.0 name: GeForce RTX 2070 SUPER computeCapability: 7.5
# coreClock: 1.785GHz coreCount: 40 deviceMemorySize: 8.00GiB deviceMemoryBandwidth: 417.29GiB/s
# 2021-04-03 11:51:44.734976: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library cudart64_110.dll
# 2021-04-03 11:51:44.738520: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library cublas64_11.dll
# 2021-04-03 11:51:44.738545: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library cublasLt64_11.dll
# 2021-04-03 11:51:44.740713: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library cufft64_10.dll
# 2021-04-03 11:51:44.741572: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library curand64_10.dll
# 2021-04-03 11